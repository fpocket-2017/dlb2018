# %% [markdown]
# # 文字と図形からなる標章の生成

# %% [markdown]
# - 全結合層５層
# - 潜在空間の次元=10
# - 画像サイズ=(256, 256)
# - 学習データ数=14000
# - テストデータ数=1000
# - 学習エポック数=588

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from PIL import Image, ImageOps

# %matplotlib inline

# %%
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from tensorflow.examples.tutorials.mnist import input_data

# %%
import os
import re
import pickle

# %%
rng = np.random.RandomState(1234)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
class SWITCH:
  IS_IMGOBJ_SAVED = True

# %%
class PATH:
  class DPATH:
    ORIGINAL = 'drive/My Drive/Public/Data/20190225+2206/'
    OBJ = 'drive/My Drive/Public/Data/20190310+2259/'

# %%
class Directory:
  def __init__(self, dpath):
    self.dpath = dpath
    self.fnames = []
  
  def get_fnames(self):
    fnames = os.listdir(self.dpath)
    
    for fname in fnames:
      if re.match(r'^.*\.JPG$', fname) is not None:
        self.fnames.append(fname)
    
    return True
  
  def escape_fnames(self):
    _fnames = []
    for idx, fname in enumerate(self.fnames):
      if ((idx+1) % 100) == 0:
        print('Processing: {}/{}'.format(idx+1, len(self.fnames)))
      
      _fnames.append(re.sub(r'\\', '\\\\', fname))
     
    self.fnames = _fnames
    
    return True
  
  def __call__(self):
    self.get_fnames()
    self.escape_fnames()
    
    return True

# %%
directory_obj = Directory(PATH.DPATH.ORIGINAL)
directory_obj()
# Out:
# Processing: 100/23576
# Processing: 200/23576
# Processing: 300/23576
# Processing: 400/23576
# Processing: 500/23576
# Processing: 600/23576
# Processing: 700/23576
# Processing: 800/23576
# Processing: 900/23576
# Processing: 1000/23576
# Processing: 1100/23576
# Processing: 1200/23576
# Processing: 1300/23576
# Processing: 1400/23576
# Processing: 1500/23576
# Processing: 1600/23576
# Processing: 1700/23576
# Processing: 1800/23576
# Processing: 1900/23576
# Processing: 2000/23576
# Processing: 2100/23576
# Processing: 2200/23576
# Processing: 2300/23576
# Processing: 2400/23576
# Processing: 2500/23576
# Processing: 2600/23576
# Processing: 2700/23576
# Processing: 2800/23576
# Processing: 2900/23576
# Processing: 3000/23576
# Processing: 3100/23576
# Processing: 3200/23576
# Processing: 3300/23576
# Processing: 3400/23576
# Processing: 3500/23576
# Processing: 3600/23576
# Processing: 3700/23576
# Processing: 3800/23576
# Processing: 3900/23576
# Processing: 4000/23576
# Processing: 4100/23576
# Processing: 4200/23576
# Processing: 4300/23576
# Processing: 4400/23576
# Processing: 4500/23576
# Processing: 4600/23576
# Processing: 4700/23576
# Processing: 4800/23576
# Processing: 4900/23576
# Processing: 5000/23576
# Processing: 5100/23576
# Processing: 5200/23576
# Processing: 5300/23576
# Processing: 5400/23576
# Processing: 5500/23576
# Processing: 5600/23576
# Processing: 5700/23576
# Processing: 5800/23576
# Processing: 5900/23576
# Processing: 6000/23576
# Processing: 6100/23576
# Processing: 6200/23576
# Processing: 6300/23576
# Processing: 6400/23576
# Processing: 6500/23576
# Processing: 6600/23576
# Processing: 6700/23576
# Processing: 6800/23576
# Processing: 6900/23576
# Processing: 7000/23576
# Processing: 7100/23576
# Processing: 7200/23576
# Processing: 7300/23576
# Processing: 7400/23576
# Processing: 7500/23576
# Processing: 7600/23576
# Processing: 7700/23576
# Processing: 7800/23576
# Processing: 7900/23576
# Processing: 8000/23576
# Processing: 8100/23576
# Processing: 8200/23576
# Processing: 8300/23576
# Processing: 8400/23576
# Processing: 8500/23576
# Processing: 8600/23576
# Processing: 8700/23576
# Processing: 8800/23576
# Processing: 8900/23576
# Processing: 9000/23576
# Processing: 9100/23576
# Processing: 9200/23576
# Processing: 9300/23576
# Processing: 9400/23576
# Processing: 9500/23576
# Processing: 9600/23576
# Processing: 9700/23576
# Processing: 9800/23576
# Processing: 9900/23576
# Processing: 10000/23576
# Processing: 10100/23576
# Processing: 10200/23576
# Processing: 10300/23576
# Processing: 10400/23576
# Processing: 10500/23576
# Processing: 10600/23576
# Processing: 10700/23576
# Processing: 10800/23576
# Processing: 10900/23576
# Processing: 11000/23576
# Processing: 11100/23576
# Processing: 11200/23576
# Processing: 11300/23576
# Processing: 11400/23576
# Processing: 11500/23576
# Processing: 11600/23576
# Processing: 11700/23576
# Processing: 11800/23576
# Processing: 11900/23576
# Processing: 12000/23576
# Processing: 12100/23576
# Processing: 12200/23576
# Processing: 12300/23576
# Processing: 12400/23576
# Processing: 12500/23576
# Processing: 12600/23576
# Processing: 12700/23576
# Processing: 12800/23576
# Processing: 12900/23576
# Processing: 13000/23576
# Processing: 13100/23576
# Processing: 13200/23576
# Processing: 13300/23576
# Processing: 13400/23576
# Processing: 13500/23576
# Processing: 13600/23576
# Processing: 13700/23576
# Processing: 13800/23576
# Processing: 13900/23576
# Processing: 14000/23576
# Processing: 14100/23576
# Processing: 14200/23576
# Processing: 14300/23576
# Processing: 14400/23576
# Processing: 14500/23576
# Processing: 14600/23576
# Processing: 14700/23576
# Processing: 14800/23576
# Processing: 14900/23576
# Processing: 15000/23576
# Processing: 15100/23576
# Processing: 15200/23576
# Processing: 15300/23576
# Processing: 15400/23576
# Processing: 15500/23576
# Processing: 15600/23576
# Processing: 15700/23576
# Processing: 15800/23576
# Processing: 15900/23576
# Processing: 16000/23576
# Processing: 16100/23576
# Processing: 16200/23576
# Processing: 16300/23576
# Processing: 16400/23576
# Processing: 16500/23576
# Processing: 16600/23576
# Processing: 16700/23576
# Processing: 16800/23576
# Processing: 16900/23576
# Processing: 17000/23576
# Processing: 17100/23576
# Processing: 17200/23576
# Processing: 17300/23576
# Processing: 17400/23576
# Processing: 17500/23576
# Processing: 17600/23576
# Processing: 17700/23576
# Processing: 17800/23576
# Processing: 17900/23576
# Processing: 18000/23576
# Processing: 18100/23576
# Processing: 18200/23576
# Processing: 18300/23576
# Processing: 18400/23576
# Processing: 18500/23576
# Processing: 18600/23576
# Processing: 18700/23576
# Processing: 18800/23576
# Processing: 18900/23576
# Processing: 19000/23576
# Processing: 19100/23576
# Processing: 19200/23576
# Processing: 19300/23576
# Processing: 19400/23576
# Processing: 19500/23576
# Processing: 19600/23576
# Processing: 19700/23576
# Processing: 19800/23576
# Processing: 19900/23576
# Processing: 20000/23576
# Processing: 20100/23576
# Processing: 20200/23576
# Processing: 20300/23576
# Processing: 20400/23576
# Processing: 20500/23576
# Processing: 20600/23576
# Processing: 20700/23576
# Processing: 20800/23576
# Processing: 20900/23576
# Processing: 21000/23576
# Processing: 21100/23576
# Processing: 21200/23576
# Processing: 21300/23576
# Processing: 21400/23576
# Processing: 21500/23576
# Processing: 21600/23576
# Processing: 21700/23576
# Processing: 21800/23576
# Processing: 21900/23576
# Processing: 22000/23576
# Processing: 22100/23576
# Processing: 22200/23576
# Processing: 22300/23576
# Processing: 22400/23576
# Processing: 22500/23576
# Processing: 22600/23576
# Processing: 22700/23576
# Processing: 22800/23576
# Processing: 22900/23576
# Processing: 23000/23576
# Processing: 23100/23576
# Processing: 23200/23576
# Processing: 23300/23576
# Processing: 23400/23576
# Processing: 23500/23576
# True

# %%
class MyImage:
  IMG_TOTAL_NUM = 15000
  IMG_PREVIEW_NUM = 10
  
  IMG_SIZE_WIDTH = 256
  IMG_SIZE_HEIGHT = 256
  
  IMG_SIZE = (IMG_SIZE_WIDTH, IMG_SIZE_HEIGHT)
  
  IMG_FORMAT = 'L'
  
  BATCH_SIZE = 100

  def __init__(self):
    self.imgs = []

  @staticmethod
  def _save_img_obj(dpath, suffix, imgs):
    print('Saving images object')
    
    print('Saving imgs obj')
    with open('{}imgs{}.bin'.format(dpath, suffix), 'wb') as web:
      pickle.dump(imgs, web)
     
    return True

  @staticmethod
  def _load_img_obj(dpath, suffix):
    print('Loading images object')
    
    with open('{}imgs{}.bin'.format(dpath, suffix), 'rb') as web:
      imgs = pickle.load(web)
      
    return imgs
    
  def get_images(self, dpath_original, fnames, dpath_obj):
    print('Getting images')
    
    iterations = MyImage.IMG_TOTAL_NUM // MyImage.BATCH_SIZE
    
    for i in range(iterations):
      print('Iteration: ''{}/{}'.format(i+1, iterations))
      
      if SWITCH.IS_IMGOBJ_SAVED:
        imgs = MyImage._load_img_obj(dpath_obj, '_{}'.format(i))
      else:
        imgs = [Image.open(dpath_original + fname) for fname in fnames[i*MyImage.BATCH_SIZE:(i+1)*MyImage.BATCH_SIZE]]
        imgs = [img.resize(MyImage.IMG_SIZE) for img in imgs]
        imgs = [img.convert(MyImage.IMG_FORMAT) for img in imgs]
        imgs = [ImageOps.invert(img) for img in imgs]
      
        if IS_IMGOBJ_SAVED:
          MyImage._save_img_obj(dpath_obj, '_{}'.format(i), imgs)
      
      self.imgs.extend(imgs)
      
    return True
  
  def preview_images(self):
    for img in self.imgs[:MyImage.IMG_PREVIEW_NUM]:
      plt.imshow(img)
      plt.show()

# %%
img_obj = MyImage()
img_obj.get_images(directory_obj.dpath, directory_obj.fnames, PATH.DPATH.OBJ)
# Out:
# Getting images
# Iteration: 1/150
# Loading images object
# Iteration: 2/150
# Loading images object
# Iteration: 3/150
# Loading images object
# Iteration: 4/150
# Loading images object
# Iteration: 5/150
# Loading images object
# Iteration: 6/150
# Loading images object
# Iteration: 7/150
# Loading images object
# Iteration: 8/150
# Loading images object
# Iteration: 9/150
# Loading images object
# Iteration: 10/150
# Loading images object
# Iteration: 11/150
# Loading images object
# Iteration: 12/150
# Loading images object
# Iteration: 13/150
# Loading images object
# Iteration: 14/150
# Loading images object
# Iteration: 15/150
# Loading images object
# Iteration: 16/150
# Loading images object
# Iteration: 17/150
# Loading images object
# Iteration: 18/150
# Loading images object
# Iteration: 19/150
# Loading images object
# Iteration: 20/150
# Loading images object
# Iteration: 21/150
# Loading images object
# Iteration: 22/150
# Loading images object
# Iteration: 23/150
# Loading images object
# Iteration: 24/150
# Loading images object
# Iteration: 25/150
# Loading images object
# Iteration: 26/150
# Loading images object
# Iteration: 27/150
# Loading images object
# Iteration: 28/150
# Loading images object
# Iteration: 29/150
# Loading images object
# Iteration: 30/150
# Loading images object
# Iteration: 31/150
# Loading images object
# Iteration: 32/150
# Loading images object
# Iteration: 33/150
# Loading images object
# Iteration: 34/150
# Loading images object
# Iteration: 35/150
# Loading images object
# Iteration: 36/150
# Loading images object
# Iteration: 37/150
# Loading images object
# Iteration: 38/150
# Loading images object
# Iteration: 39/150
# Loading images object
# Iteration: 40/150
# Loading images object
# Iteration: 41/150
# Loading images object
# Iteration: 42/150
# Loading images object
# Iteration: 43/150
# Loading images object
# Iteration: 44/150
# Loading images object
# Iteration: 45/150
# Loading images object
# Iteration: 46/150
# Loading images object
# Iteration: 47/150
# Loading images object
# Iteration: 48/150
# Loading images object
# Iteration: 49/150
# Loading images object
# Iteration: 50/150
# Loading images object
# Iteration: 51/150
# Loading images object
# Iteration: 52/150
# Loading images object
# Iteration: 53/150
# Loading images object
# Iteration: 54/150
# Loading images object
# Iteration: 55/150
# Loading images object
# Iteration: 56/150
# Loading images object
# Iteration: 57/150
# Loading images object
# Iteration: 58/150
# Loading images object
# Iteration: 59/150
# Loading images object
# Iteration: 60/150
# Loading images object
# Iteration: 61/150
# Loading images object
# Iteration: 62/150
# Loading images object
# Iteration: 63/150
# Loading images object
# Iteration: 64/150
# Loading images object
# Iteration: 65/150
# Loading images object
# Iteration: 66/150
# Loading images object
# Iteration: 67/150
# Loading images object
# Iteration: 68/150
# Loading images object
# Iteration: 69/150
# Loading images object
# Iteration: 70/150
# Loading images object
# Iteration: 71/150
# Loading images object
# Iteration: 72/150
# Loading images object
# Iteration: 73/150
# Loading images object
# Iteration: 74/150
# Loading images object
# Iteration: 75/150
# Loading images object
# Iteration: 76/150
# Loading images object
# Iteration: 77/150
# Loading images object
# Iteration: 78/150
# Loading images object
# Iteration: 79/150
# Loading images object
# Iteration: 80/150
# Loading images object
# Iteration: 81/150
# Loading images object
# Iteration: 82/150
# Loading images object
# Iteration: 83/150
# Loading images object
# Iteration: 84/150
# Loading images object
# Iteration: 85/150
# Loading images object
# Iteration: 86/150
# Loading images object
# Iteration: 87/150
# Loading images object
# Iteration: 88/150
# Loading images object
# Iteration: 89/150
# Loading images object
# Iteration: 90/150
# Loading images object
# Iteration: 91/150
# Loading images object
# Iteration: 92/150
# Loading images object
# Iteration: 93/150
# Loading images object
# Iteration: 94/150
# Loading images object
# Iteration: 95/150
# Loading images object
# Iteration: 96/150
# Loading images object
# Iteration: 97/150
# Loading images object
# Iteration: 98/150
# Loading images object
# Iteration: 99/150
# Loading images object
# Iteration: 100/150
# Loading images object
# Iteration: 101/150
# Loading images object
# Iteration: 102/150
# Loading images object
# Iteration: 103/150
# Loading images object
# Iteration: 104/150
# Loading images object
# Iteration: 105/150
# Loading images object
# Iteration: 106/150
# Loading images object
# Iteration: 107/150
# Loading images object
# Iteration: 108/150
# Loading images object
# Iteration: 109/150
# Loading images object
# Iteration: 110/150
# Loading images object
# Iteration: 111/150
# Loading images object
# Iteration: 112/150
# Loading images object
# Iteration: 113/150
# Loading images object
# Iteration: 114/150
# Loading images object
# Iteration: 115/150
# Loading images object
# Iteration: 116/150
# Loading images object
# Iteration: 117/150
# Loading images object
# Iteration: 118/150
# Loading images object
# Iteration: 119/150
# Loading images object
# Iteration: 120/150
# Loading images object
# Iteration: 121/150
# Loading images object
# Iteration: 122/150
# Loading images object
# Iteration: 123/150
# Loading images object
# Iteration: 124/150
# Loading images object
# Iteration: 125/150
# Loading images object
# Iteration: 126/150
# Loading images object
# Iteration: 127/150
# Loading images object
# Iteration: 128/150
# Loading images object
# Iteration: 129/150
# Loading images object
# Iteration: 130/150
# Loading images object
# Iteration: 131/150
# Loading images object
# Iteration: 132/150
# Loading images object
# Iteration: 133/150
# Loading images object
# Iteration: 134/150
# Loading images object
# Iteration: 135/150
# Loading images object
# Iteration: 136/150
# Loading images object
# Iteration: 137/150
# Loading images object
# Iteration: 138/150
# Loading images object
# Iteration: 139/150
# Loading images object
# Iteration: 140/150
# Loading images object
# Iteration: 141/150
# Loading images object
# Iteration: 142/150
# Loading images object
# Iteration: 143/150
# Loading images object
# Iteration: 144/150
# Loading images object
# Iteration: 145/150
# Loading images object
# Iteration: 146/150
# Loading images object
# Iteration: 147/150
# Loading images object
# Iteration: 148/150
# Loading images object
# Iteration: 149/150
# Loading images object
# Iteration: 150/150
# Loading images object
# True

# %%
img_obj.preview_images()

# %%
class Data:
  VALID_DATA_NUM = 1000
  BATCH_SIZE = 100
  
  def __init__(self):
    self.x_train = None
    self.x_valid = None
    
  def make_numpy_array(self, imgs):
    print('Making numpy array')
    self.x_train = np.array([np.asarray(img) for img in imgs[:-Data.VALID_DATA_NUM]])
    self.x_valid = np.array([np.asarray(img) for img in imgs[-Data.VALID_DATA_NUM:]])
  
    return True
  
  def standardize(self):
    print('Standardizing')
    self.x_train = self.x_train / 255
    self.x_valid = self.x_valid / 255
    
    return True
  
  def reshape(self):
    self.x_train = self.x_train.reshape(-1, MyImage.IMG_SIZE_WIDTH*MyImage.IMG_SIZE_HEIGHT)
    self.x_valid = self.x_valid.reshape(-1, MyImage.IMG_SIZE_WIDTH*MyImage.IMG_SIZE_HEIGHT)

# %%
data_obj = Data()
data_obj.make_numpy_array(img_obj.imgs)
# Out:
# Making numpy array
# True

# %%
data_obj.standardize()
# Out:
# Standardizing
# True

# %%
data_obj.reshape()

# %%
class Model:
  Z_DIM = 10
  
  @staticmethod
  def initialize():
    tf.reset_default_graph()

  @staticmethod
  def tf_log(x):
      return tf.log(tf.clip_by_value(x, 1e-10, x))

  @staticmethod
  def encoder(x, is_training):
      with tf.variable_scope('Encoder', reuse=tf.AUTO_REUSE):
          h = tf.layers.Dense(units=512, activation=tf.nn.relu)(x)        
          h = tf.layers.Dense(units=1024, activation=tf.nn.relu)(h)        
          h = tf.layers.Dense(units=1024, activation=tf.nn.relu)(h)        
          h = tf.layers.Dense(units=32*32, activation=tf.nn.relu)(h)

          mean = tf.layers.Dense(units=Model.Z_DIM)(h)
          var = tf.layers.Dense(units=Model.Z_DIM, activation=tf.nn.softplus)(h)

      return mean, var

  @staticmethod
  def sampling_z(mean, var):
      epsilon = tf.random_normal(shape=tf.shape(mean))
      z = mean + tf.sqrt(var) * epsilon
      return z

  @staticmethod
  def decoder(z, is_training):
      with tf.variable_scope('Decoder', reuse=tf.AUTO_REUSE):
          h = tf.layers.Dense(units=512, activation=tf.nn.relu)(z)
          h = tf.layers.Dense(units=1024, activation=tf.nn.relu)(h)        
          h = tf.layers.Dense(units=1024, activation=tf.nn.relu)(h)        
          h = tf.layers.Dense(units=512, activation=tf.nn.relu)(h)         
          y = tf.layers.Dense(units=256*256, activation=tf.nn.sigmoid)(h)

      return y

  @staticmethod
  def lower_bound(x, is_training):
      #Encode
      mean, var = Model.encoder(x, is_training)
      KL = -0.5 * tf.reduce_mean(tf.reduce_sum(1 + Model.tf_log(var) - mean**2 - var, axis=1))

      #Z
      z = Model.sampling_z(mean, var)

      #Decode
      y = Model.decoder(z, is_training)
      reconstruction = tf.reduce_mean(tf.reduce_sum(x * Model.tf_log(y) + (1 - x) * Model.tf_log(1 - y), axis=1))

      lower_bound = [-KL, reconstruction]

      return lower_bound

# %%
x = tf.placeholder(tf.float32, [None, MyImage.IMG_SIZE_WIDTH*MyImage.IMG_SIZE_HEIGHT])
is_training = tf.placeholder(tf.bool, shape=())

lower_bound = Model.lower_bound(x, is_training)

cost = -tf.reduce_sum(lower_bound) # 下界を最大化するため、マイナスをとる

optimizer = tf.train.AdamOptimizer(learning_rate=0.00005)

train = optimizer.minimize(cost)

valid = tf.reduce_sum(lower_bound)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
class Train:
  N_EPOCHS = 1000
  
  BATCH_SIZE = 100
  N_BATCHES = (MyImage.IMG_TOTAL_NUM - Data.VALID_DATA_NUM)// BATCH_SIZE


  def __init__(self):
    self.sess = tf.Session()

  def initialize(self):
    init = tf.global_variables_initializer()
    self.sess.run(init)
    
    return True
  
  def __call__(self, x_train, x_valid):
    for epoch in range(Train.N_EPOCHS):
      print('Processing epoch: {}/{}'.format(epoch+1, Train.N_EPOCHS))
      
      rng.shuffle(x_train)
      lower_bound_all = []

      for i in range(Train.N_BATCHES):
        start = i * Train.BATCH_SIZE
        end = start + Train.BATCH_SIZE
        
        _, lowerbound = self.sess.run([train, lower_bound], feed_dict={x: x_train[start:end], is_training: True})

        lower_bound_all.append(lowerbound)

      lower_bound_all = np.mean(lower_bound_all, axis=0)
      lower_bound_valid = self.sess.run(valid, feed_dict={x: x_valid, is_training: False})

      print(
          'EPOCH: {:005}, Train Lower Bound: {:.1f}, ({:.1f}, {:.1f}), Valid Lower Bound: {:.1f}'.format(
            epoch+1,
            np.sum(lower_bound_all),
            lower_bound_all[0],
            lower_bound_all[1],
            lower_bound_valid
        )
      )
      
    return True

# %%
train_obj = Train()
train_obj.initialize()
# Out:
# True

# %%
train_obj(data_obj.x_train, data_obj.x_valid)
# Out:
# Processing epoch: 1/1000
# EPOCH: 00001, Train Lower Bound: -32623.1, (-239.0, -32384.2), Valid Lower Bound: -27627.0
# Processing epoch: 2/1000
# EPOCH: 00002, Train Lower Bound: -26583.4, (-115.6, -26467.8), Valid Lower Bound: -25801.0
# Processing epoch: 3/1000
# EPOCH: 00003, Train Lower Bound: -24864.6, (-52.0, -24812.6), Valid Lower Bound: -24404.7
# Processing epoch: 4/1000
# EPOCH: 00004, Train Lower Bound: -24102.0, (-52.5, -24049.6), Valid Lower Bound: -24002.8
# Processing epoch: 5/1000
# EPOCH: 00005, Train Lower Bound: -23740.1, (-59.1, -23680.9), Valid Lower Bound: -23724.0
# Processing epoch: 6/1000
# EPOCH: 00006, Train Lower Bound: -23499.9, (-55.9, -23444.0), Valid Lower Bound: -23518.7
# Processing epoch: 7/1000
# EPOCH: 00007, Train Lower Bound: -23362.2, (-52.0, -23310.2), Valid Lower Bound: -23371.6
# Processing epoch: 8/1000
# EPOCH: 00008, Train Lower Bound: -23260.3, (-53.8, -23206.5), Valid Lower Bound: -23202.1
# Processing epoch: 9/1000
# EPOCH: 00009, Train Lower Bound: -23029.3, (-60.2, -22969.1), Valid Lower Bound: -22942.3
# Processing epoch: 10/1000
# EPOCH: 00010, Train Lower Bound: -22686.0, (-70.2, -22615.9), Valid Lower Bound: -22674.1
# Processing epoch: 11/1000
# EPOCH: 00011, Train Lower Bound: -22505.2, (-65.6, -22439.6), Valid Lower Bound: -22589.5
# Processing epoch: 12/1000
# EPOCH: 00012, Train Lower Bound: -22424.4, (-62.0, -22362.5), Valid Lower Bound: -22451.9
# Processing epoch: 13/1000
# EPOCH: 00013, Train Lower Bound: -22354.8, (-63.2, -22291.6), Valid Lower Bound: -22378.7
# Processing epoch: 14/1000
# EPOCH: 00014, Train Lower Bound: -22261.2, (-66.6, -22194.6), Valid Lower Bound: -22289.2
# Processing epoch: 15/1000
# EPOCH: 00015, Train Lower Bound: -22171.0, (-68.1, -22102.9), Valid Lower Bound: -22295.1
# Processing epoch: 16/1000
# EPOCH: 00016, Train Lower Bound: -22050.3, (-65.3, -21984.9), Valid Lower Bound: -22096.7
# Processing epoch: 17/1000
# EPOCH: 00017, Train Lower Bound: -21924.9, (-61.1, -21863.8), Valid Lower Bound: -21953.4
# Processing epoch: 18/1000
# EPOCH: 00018, Train Lower Bound: -21866.6, (-57.9, -21808.7), Valid Lower Bound: -21877.4
# Processing epoch: 19/1000
# EPOCH: 00019, Train Lower Bound: -21755.1, (-60.4, -21694.7), Valid Lower Bound: -21716.2
# Processing epoch: 20/1000
# EPOCH: 00020, Train Lower Bound: -21639.0, (-61.8, -21577.2), Valid Lower Bound: -21567.0
# Processing epoch: 21/1000
# EPOCH: 00021, Train Lower Bound: -21529.2, (-60.1, -21469.1), Valid Lower Bound: -21496.4
# Processing epoch: 22/1000
# EPOCH: 00022, Train Lower Bound: -21474.6, (-57.7, -21416.9), Valid Lower Bound: -21457.1
# Processing epoch: 23/1000
# EPOCH: 00023, Train Lower Bound: -21454.0, (-56.1, -21397.9), Valid Lower Bound: -21451.3
# Processing epoch: 24/1000
# EPOCH: 00024, Train Lower Bound: -21428.9, (-55.0, -21373.9), Valid Lower Bound: -21409.2
# Processing epoch: 25/1000
# EPOCH: 00025, Train Lower Bound: -21409.1, (-54.4, -21354.7), Valid Lower Bound: -21390.6
# Processing epoch: 26/1000
# EPOCH: 00026, Train Lower Bound: -21388.5, (-54.0, -21334.5), Valid Lower Bound: -21387.6
# Processing epoch: 27/1000
# EPOCH: 00027, Train Lower Bound: -21377.5, (-53.4, -21324.1), Valid Lower Bound: -21370.7
# Processing epoch: 28/1000
# EPOCH: 00028, Train Lower Bound: -21356.3, (-53.3, -21303.0), Valid Lower Bound: -21354.3
# Processing epoch: 29/1000
# EPOCH: 00029, Train Lower Bound: -21335.0, (-52.8, -21282.2), Valid Lower Bound: -21333.9
# Processing epoch: 30/1000
# EPOCH: 00030, Train Lower Bound: -21314.0, (-52.9, -21261.1), Valid Lower Bound: -21308.5
# Processing epoch: 31/1000
# EPOCH: 00031, Train Lower Bound: -21281.7, (-53.1, -21228.5), Valid Lower Bound: -21264.3
# Processing epoch: 32/1000
# EPOCH: 00032, Train Lower Bound: -21250.7, (-53.4, -21197.3), Valid Lower Bound: -21191.2
# Processing epoch: 33/1000
# EPOCH: 00033, Train Lower Bound: -21152.0, (-55.4, -21096.5), Valid Lower Bound: -21047.7
# Processing epoch: 34/1000
# EPOCH: 00034, Train Lower Bound: -21074.1, (-54.9, -21019.2), Valid Lower Bound: -20995.8
# Processing epoch: 35/1000
# EPOCH: 00035, Train Lower Bound: -21009.6, (-54.6, -20955.0), Valid Lower Bound: -20884.8
# Processing epoch: 36/1000
# EPOCH: 00036, Train Lower Bound: -20910.9, (-56.2, -20854.7), Valid Lower Bound: -20786.3
# Processing epoch: 37/1000
# EPOCH: 00037, Train Lower Bound: -20842.8, (-56.2, -20786.6), Valid Lower Bound: -20764.8
# Processing epoch: 38/1000
# EPOCH: 00038, Train Lower Bound: -20803.1, (-55.9, -20747.1), Valid Lower Bound: -20687.1
# Processing epoch: 39/1000
# EPOCH: 00039, Train Lower Bound: -20757.2, (-56.3, -20700.9), Valid Lower Bound: -20665.1
# Processing epoch: 40/1000
# EPOCH: 00040, Train Lower Bound: -20732.2, (-56.1, -20676.1), Valid Lower Bound: -20630.3
# Processing epoch: 41/1000
# EPOCH: 00041, Train Lower Bound: -20706.8, (-56.4, -20650.4), Valid Lower Bound: -20625.6
# Processing epoch: 42/1000
# EPOCH: 00042, Train Lower Bound: -20667.8, (-56.8, -20611.0), Valid Lower Bound: -20569.1
# Processing epoch: 43/1000
# EPOCH: 00043, Train Lower Bound: -20623.8, (-57.2, -20566.6), Valid Lower Bound: -20505.5
# Processing epoch: 44/1000
# EPOCH: 00044, Train Lower Bound: -20565.6, (-57.7, -20507.9), Valid Lower Bound: -20465.1
# Processing epoch: 45/1000
# EPOCH: 00045, Train Lower Bound: -20522.3, (-57.8, -20464.6), Valid Lower Bound: -20435.2
# Processing epoch: 46/1000
# EPOCH: 00046, Train Lower Bound: -20489.3, (-58.0, -20431.4), Valid Lower Bound: -20413.4
# Processing epoch: 47/1000
# EPOCH: 00047, Train Lower Bound: -20462.0, (-58.0, -20404.0), Valid Lower Bound: -20397.7
# Processing epoch: 48/1000
# EPOCH: 00048, Train Lower Bound: -20432.2, (-58.0, -20374.2), Valid Lower Bound: -20365.5
# Processing epoch: 49/1000
# EPOCH: 00049, Train Lower Bound: -20398.8, (-58.3, -20340.5), Valid Lower Bound: -20354.7
# Processing epoch: 50/1000
# EPOCH: 00050, Train Lower Bound: -20380.3, (-58.1, -20322.2), Valid Lower Bound: -20314.4
# Processing epoch: 51/1000
# EPOCH: 00051, Train Lower Bound: -20362.1, (-58.1, -20304.0), Valid Lower Bound: -20312.4
# Processing epoch: 52/1000
# EPOCH: 00052, Train Lower Bound: -20331.5, (-58.3, -20273.2), Valid Lower Bound: -20328.9
# Processing epoch: 53/1000
# EPOCH: 00053, Train Lower Bound: -20306.3, (-58.3, -20248.0), Valid Lower Bound: -20250.1
# Processing epoch: 54/1000
# EPOCH: 00054, Train Lower Bound: -20289.2, (-58.0, -20231.2), Valid Lower Bound: -20232.9
# Processing epoch: 55/1000
# EPOCH: 00055, Train Lower Bound: -20237.2, (-58.8, -20178.4), Valid Lower Bound: -20192.9
# Processing epoch: 56/1000
# EPOCH: 00056, Train Lower Bound: -20209.8, (-58.4, -20151.4), Valid Lower Bound: -20177.1
# Processing epoch: 57/1000
# EPOCH: 00057, Train Lower Bound: -20174.2, (-58.8, -20115.4), Valid Lower Bound: -20144.9
# Processing epoch: 58/1000
# EPOCH: 00058, Train Lower Bound: -20155.9, (-58.7, -20097.2), Valid Lower Bound: -20149.1
# Processing epoch: 59/1000
# EPOCH: 00059, Train Lower Bound: -20128.2, (-58.8, -20069.3), Valid Lower Bound: -20121.3
# Processing epoch: 60/1000
# EPOCH: 00060, Train Lower Bound: -20101.5, (-58.8, -20042.7), Valid Lower Bound: -20079.0
# Processing epoch: 61/1000
# EPOCH: 00061, Train Lower Bound: -20083.6, (-58.9, -20024.7), Valid Lower Bound: -20053.7
# Processing epoch: 62/1000
# EPOCH: 00062, Train Lower Bound: -20047.0, (-59.3, -19987.6), Valid Lower Bound: -20039.7
# Processing epoch: 63/1000
# EPOCH: 00063, Train Lower Bound: -20015.3, (-59.5, -19955.8), Valid Lower Bound: -20025.8
# Processing epoch: 64/1000
# EPOCH: 00064, Train Lower Bound: -19973.1, (-59.6, -19913.4), Valid Lower Bound: -19979.7
# Processing epoch: 65/1000
# EPOCH: 00065, Train Lower Bound: -19956.8, (-59.7, -19897.2), Valid Lower Bound: -19975.9
# Processing epoch: 66/1000
# EPOCH: 00066, Train Lower Bound: -19935.8, (-59.5, -19876.3), Valid Lower Bound: -19963.8
# Processing epoch: 67/1000
# EPOCH: 00067, Train Lower Bound: -19915.7, (-59.6, -19856.1), Valid Lower Bound: -19958.7
# Processing epoch: 68/1000
# EPOCH: 00068, Train Lower Bound: -19889.9, (-59.7, -19830.2), Valid Lower Bound: -19946.5
# Processing epoch: 69/1000
# EPOCH: 00069, Train Lower Bound: -19872.9, (-59.7, -19813.2), Valid Lower Bound: -19922.8
# Processing epoch: 70/1000
# EPOCH: 00070, Train Lower Bound: -19865.9, (-59.5, -19806.4), Valid Lower Bound: -19996.0
# Processing epoch: 71/1000
# EPOCH: 00071, Train Lower Bound: -19852.8, (-59.5, -19793.2), Valid Lower Bound: -19939.2
# Processing epoch: 72/1000
# EPOCH: 00072, Train Lower Bound: -19845.5, (-59.2, -19786.3), Valid Lower Bound: -19939.7
# Processing epoch: 73/1000
# EPOCH: 00073, Train Lower Bound: -19824.4, (-59.3, -19765.1), Valid Lower Bound: -19948.5
# Processing epoch: 74/1000
# EPOCH: 00074, Train Lower Bound: -19802.6, (-59.4, -19743.2), Valid Lower Bound: -19925.0
# Processing epoch: 75/1000
# EPOCH: 00075, Train Lower Bound: -19798.1, (-59.3, -19738.8), Valid Lower Bound: -19920.8
# Processing epoch: 76/1000
# EPOCH: 00076, Train Lower Bound: -19779.9, (-59.4, -19720.5), Valid Lower Bound: -19917.6
# Processing epoch: 77/1000
# EPOCH: 00077, Train Lower Bound: -19774.6, (-59.2, -19715.4), Valid Lower Bound: -19937.7
# Processing epoch: 78/1000
# EPOCH: 00078, Train Lower Bound: -19764.3, (-59.1, -19705.3), Valid Lower Bound: -19904.6
# Processing epoch: 79/1000
# EPOCH: 00079, Train Lower Bound: -19760.5, (-58.8, -19701.7), Valid Lower Bound: -19900.2
# Processing epoch: 80/1000
# EPOCH: 00080, Train Lower Bound: -19752.3, (-58.7, -19693.6), Valid Lower Bound: -19910.9
# Processing epoch: 81/1000
# EPOCH: 00081, Train Lower Bound: -19734.0, (-58.8, -19675.2), Valid Lower Bound: -19898.3
# Processing epoch: 82/1000
# EPOCH: 00082, Train Lower Bound: -19727.2, (-58.9, -19668.3), Valid Lower Bound: -19893.3
# Processing epoch: 83/1000
# EPOCH: 00083, Train Lower Bound: -19718.7, (-58.8, -19659.9), Valid Lower Bound: -19928.9
# Processing epoch: 84/1000
# EPOCH: 00084, Train Lower Bound: -19706.2, (-58.6, -19647.7), Valid Lower Bound: -19913.0
# Processing epoch: 85/1000
# EPOCH: 00085, Train Lower Bound: -19726.4, (-58.1, -19668.3), Valid Lower Bound: -19920.0
# Processing epoch: 86/1000
# EPOCH: 00086, Train Lower Bound: -19693.8, (-58.6, -19635.2), Valid Lower Bound: -19921.3
# Processing epoch: 87/1000
# EPOCH: 00087, Train Lower Bound: -19675.0, (-58.7, -19616.2), Valid Lower Bound: -19885.6
# Processing epoch: 88/1000
# EPOCH: 00088, Train Lower Bound: -19665.6, (-58.7, -19606.9), Valid Lower Bound: -19885.6
# Processing epoch: 89/1000
# EPOCH: 00089, Train Lower Bound: -19650.3, (-58.7, -19591.6), Valid Lower Bound: -19878.2
# Processing epoch: 90/1000
# EPOCH: 00090, Train Lower Bound: -19642.7, (-58.5, -19584.2), Valid Lower Bound: -19881.2
# Processing epoch: 91/1000
# EPOCH: 00091, Train Lower Bound: -19633.3, (-58.5, -19574.8), Valid Lower Bound: -19908.8
# Processing epoch: 92/1000
# EPOCH: 00092, Train Lower Bound: -19645.9, (-58.1, -19587.7), Valid Lower Bound: -19906.6
# Processing epoch: 93/1000
# EPOCH: 00093, Train Lower Bound: -19635.6, (-58.4, -19577.1), Valid Lower Bound: -19888.2
# Processing epoch: 94/1000
# EPOCH: 00094, Train Lower Bound: -19643.3, (-58.1, -19585.2), Valid Lower Bound: -19918.7
# Processing epoch: 95/1000
# EPOCH: 00095, Train Lower Bound: -19609.7, (-58.5, -19551.1), Valid Lower Bound: -19880.4
# Processing epoch: 96/1000
# EPOCH: 00096, Train Lower Bound: -19606.3, (-58.3, -19548.0), Valid Lower Bound: -19875.6
# Processing epoch: 97/1000
# EPOCH: 00097, Train Lower Bound: -19592.1, (-58.3, -19533.8), Valid Lower Bound: -19895.7
# Processing epoch: 98/1000
# EPOCH: 00098, Train Lower Bound: -19575.6, (-58.6, -19517.0), Valid Lower Bound: -19866.8
# Processing epoch: 99/1000
# EPOCH: 00099, Train Lower Bound: -19575.8, (-58.3, -19517.5), Valid Lower Bound: -19911.2
# Processing epoch: 100/1000
# EPOCH: 00100, Train Lower Bound: -19571.6, (-58.1, -19513.4), Valid Lower Bound: -19875.6
# Processing epoch: 101/1000
# EPOCH: 00101, Train Lower Bound: -19572.4, (-58.3, -19514.1), Valid Lower Bound: -19913.7
# Processing epoch: 102/1000
# EPOCH: 00102, Train Lower Bound: -19551.3, (-58.2, -19493.1), Valid Lower Bound: -19892.4
# Processing epoch: 103/1000
# EPOCH: 00103, Train Lower Bound: -19541.1, (-58.3, -19482.8), Valid Lower Bound: -19884.1
# Processing epoch: 104/1000
# EPOCH: 00104, Train Lower Bound: -19563.0, (-57.8, -19505.2), Valid Lower Bound: -19904.4
# Processing epoch: 105/1000
# EPOCH: 00105, Train Lower Bound: -19531.5, (-58.1, -19473.4), Valid Lower Bound: -19867.0
# Processing epoch: 106/1000
# EPOCH: 00106, Train Lower Bound: -19520.7, (-58.1, -19462.5), Valid Lower Bound: -19869.8
# Processing epoch: 107/1000
# EPOCH: 00107, Train Lower Bound: -19518.3, (-58.3, -19460.1), Valid Lower Bound: -19885.5
# Processing epoch: 108/1000
# EPOCH: 00108, Train Lower Bound: -19505.8, (-58.2, -19447.7), Valid Lower Bound: -19885.3
# Processing epoch: 109/1000
# EPOCH: 00109, Train Lower Bound: -19493.2, (-58.3, -19434.8), Valid Lower Bound: -19865.5
# Processing epoch: 110/1000
# EPOCH: 00110, Train Lower Bound: -19523.0, (-58.0, -19465.0), Valid Lower Bound: -19884.3
# Processing epoch: 111/1000
# EPOCH: 00111, Train Lower Bound: -19511.4, (-57.7, -19453.7), Valid Lower Bound: -19878.6
# Processing epoch: 112/1000
# EPOCH: 00112, Train Lower Bound: -19498.6, (-58.0, -19440.6), Valid Lower Bound: -19885.4
# Processing epoch: 113/1000
# EPOCH: 00113, Train Lower Bound: -19475.3, (-58.2, -19417.1), Valid Lower Bound: -19881.0
# Processing epoch: 114/1000
# EPOCH: 00114, Train Lower Bound: -19474.5, (-58.1, -19416.4), Valid Lower Bound: -19879.2
# Processing epoch: 115/1000
# EPOCH: 00115, Train Lower Bound: -19452.7, (-58.4, -19394.3), Valid Lower Bound: -19890.0
# Processing epoch: 116/1000
# EPOCH: 00116, Train Lower Bound: -19462.1, (-58.1, -19404.0), Valid Lower Bound: -19874.9
# Processing epoch: 117/1000
# EPOCH: 00117, Train Lower Bound: -19455.1, (-58.0, -19397.1), Valid Lower Bound: -19970.7
# Processing epoch: 118/1000
# EPOCH: 00118, Train Lower Bound: -19447.0, (-58.1, -19388.9), Valid Lower Bound: -19884.2
# Processing epoch: 119/1000
# EPOCH: 00119, Train Lower Bound: -19440.9, (-57.9, -19383.0), Valid Lower Bound: -19891.1
# Processing epoch: 120/1000
# EPOCH: 00120, Train Lower Bound: -19428.7, (-58.1, -19370.5), Valid Lower Bound: -19904.5
# Processing epoch: 121/1000
# EPOCH: 00121, Train Lower Bound: -19418.7, (-58.3, -19360.3), Valid Lower Bound: -19867.7
# Processing epoch: 122/1000
# EPOCH: 00122, Train Lower Bound: -19423.6, (-58.3, -19365.4), Valid Lower Bound: -19907.2
# Processing epoch: 123/1000
# EPOCH: 00123, Train Lower Bound: -19411.9, (-58.0, -19353.9), Valid Lower Bound: -19881.8
# Processing epoch: 124/1000
# EPOCH: 00124, Train Lower Bound: -19416.2, (-58.1, -19358.2), Valid Lower Bound: -19888.7
# Processing epoch: 125/1000
# EPOCH: 00125, Train Lower Bound: -19423.1, (-58.1, -19365.1), Valid Lower Bound: -19877.6
# Processing epoch: 126/1000
# EPOCH: 00126, Train Lower Bound: -19402.7, (-58.1, -19344.6), Valid Lower Bound: -19878.4
# Processing epoch: 127/1000
# EPOCH: 00127, Train Lower Bound: -19395.1, (-58.4, -19336.7), Valid Lower Bound: -19898.9
# Processing epoch: 128/1000
# EPOCH: 00128, Train Lower Bound: -19376.5, (-58.3, -19318.3), Valid Lower Bound: -19904.5
# Processing epoch: 129/1000
# EPOCH: 00129, Train Lower Bound: -19377.7, (-58.4, -19319.3), Valid Lower Bound: -19904.8
# Processing epoch: 130/1000
# EPOCH: 00130, Train Lower Bound: -19372.1, (-58.2, -19313.9), Valid Lower Bound: -19899.1
# Processing epoch: 131/1000
# EPOCH: 00131, Train Lower Bound: -19360.4, (-58.3, -19302.1), Valid Lower Bound: -19880.8
# Processing epoch: 132/1000
# EPOCH: 00132, Train Lower Bound: -19353.1, (-58.6, -19294.5), Valid Lower Bound: -19889.5
# Processing epoch: 133/1000
# EPOCH: 00133, Train Lower Bound: -19340.5, (-58.6, -19281.9), Valid Lower Bound: -19915.9
# Processing epoch: 134/1000
# EPOCH: 00134, Train Lower Bound: -19341.7, (-58.4, -19283.3), Valid Lower Bound: -19908.7
# Processing epoch: 135/1000
# EPOCH: 00135, Train Lower Bound: -19338.9, (-58.5, -19280.4), Valid Lower Bound: -19907.0
# Processing epoch: 136/1000
# EPOCH: 00136, Train Lower Bound: -19337.7, (-58.4, -19279.3), Valid Lower Bound: -19899.5
# Processing epoch: 137/1000
# EPOCH: 00137, Train Lower Bound: -19333.9, (-58.3, -19275.7), Valid Lower Bound: -19904.5
# Processing epoch: 138/1000
# EPOCH: 00138, Train Lower Bound: -19323.9, (-58.5, -19265.4), Valid Lower Bound: -19902.3
# Processing epoch: 139/1000
# EPOCH: 00139, Train Lower Bound: -19330.8, (-58.4, -19272.4), Valid Lower Bound: -19875.9
# Processing epoch: 140/1000
# EPOCH: 00140, Train Lower Bound: -19315.3, (-58.4, -19256.9), Valid Lower Bound: -19919.6
# Processing epoch: 141/1000
# EPOCH: 00141, Train Lower Bound: -19306.0, (-58.5, -19247.4), Valid Lower Bound: -19900.9
# Processing epoch: 142/1000
# EPOCH: 00142, Train Lower Bound: -19293.8, (-58.7, -19235.0), Valid Lower Bound: -19893.6
# Processing epoch: 143/1000
# EPOCH: 00143, Train Lower Bound: -19294.7, (-58.7, -19236.0), Valid Lower Bound: -19907.3
# Processing epoch: 144/1000
# EPOCH: 00144, Train Lower Bound: -19323.2, (-58.2, -19265.0), Valid Lower Bound: -19913.1
# Processing epoch: 145/1000
# EPOCH: 00145, Train Lower Bound: -19300.8, (-58.3, -19242.5), Valid Lower Bound: -19937.9
# Processing epoch: 146/1000
# EPOCH: 00146, Train Lower Bound: -19283.2, (-58.7, -19224.6), Valid Lower Bound: -19922.4
# Processing epoch: 147/1000
# EPOCH: 00147, Train Lower Bound: -19263.0, (-59.1, -19203.9), Valid Lower Bound: -19889.7
# Processing epoch: 148/1000
# EPOCH: 00148, Train Lower Bound: -19257.2, (-59.1, -19198.1), Valid Lower Bound: -19948.5
# Processing epoch: 149/1000
# EPOCH: 00149, Train Lower Bound: -19256.8, (-59.0, -19197.8), Valid Lower Bound: -19900.3
# Processing epoch: 150/1000
# EPOCH: 00150, Train Lower Bound: -19284.7, (-58.7, -19225.9), Valid Lower Bound: -19903.5
# Processing epoch: 151/1000
# EPOCH: 00151, Train Lower Bound: -19260.1, (-58.9, -19201.2), Valid Lower Bound: -19906.2
# Processing epoch: 152/1000
# EPOCH: 00152, Train Lower Bound: -19240.9, (-59.2, -19181.8), Valid Lower Bound: -19914.7
# Processing epoch: 153/1000
# EPOCH: 00153, Train Lower Bound: -19247.8, (-58.9, -19188.9), Valid Lower Bound: -19943.4
# Processing epoch: 154/1000
# EPOCH: 00154, Train Lower Bound: -19226.5, (-59.4, -19167.1), Valid Lower Bound: -19901.4
# Processing epoch: 155/1000
# EPOCH: 00155, Train Lower Bound: -19222.8, (-59.5, -19163.3), Valid Lower Bound: -19919.9
# Processing epoch: 156/1000
# EPOCH: 00156, Train Lower Bound: -19225.4, (-59.3, -19166.1), Valid Lower Bound: -19928.2
# Processing epoch: 157/1000
# EPOCH: 00157, Train Lower Bound: -19210.2, (-59.5, -19150.7), Valid Lower Bound: -19940.9
# Processing epoch: 158/1000
# EPOCH: 00158, Train Lower Bound: -19217.1, (-59.3, -19157.7), Valid Lower Bound: -19925.2
# Processing epoch: 159/1000
# EPOCH: 00159, Train Lower Bound: -19205.9, (-59.5, -19146.5), Valid Lower Bound: -19919.7
# Processing epoch: 160/1000
# EPOCH: 00160, Train Lower Bound: -19207.8, (-59.7, -19148.1), Valid Lower Bound: -19914.3
# Processing epoch: 161/1000
# EPOCH: 00161, Train Lower Bound: -19202.9, (-59.5, -19143.4), Valid Lower Bound: -19937.4
# Processing epoch: 162/1000
# EPOCH: 00162, Train Lower Bound: -19200.1, (-59.5, -19140.5), Valid Lower Bound: -19961.1
# Processing epoch: 163/1000
# EPOCH: 00163, Train Lower Bound: -19199.9, (-59.6, -19140.3), Valid Lower Bound: -19967.9
# Processing epoch: 164/1000
# EPOCH: 00164, Train Lower Bound: -19184.4, (-59.8, -19124.6), Valid Lower Bound: -19931.9
# Processing epoch: 165/1000
# EPOCH: 00165, Train Lower Bound: -19181.1, (-59.8, -19121.3), Valid Lower Bound: -19927.5
# Processing epoch: 166/1000
# EPOCH: 00166, Train Lower Bound: -19176.1, (-59.9, -19116.2), Valid Lower Bound: -19943.7
# Processing epoch: 167/1000
# EPOCH: 00167, Train Lower Bound: -19166.4, (-60.2, -19106.2), Valid Lower Bound: -19946.7
# Processing epoch: 168/1000
# EPOCH: 00168, Train Lower Bound: -19157.6, (-60.2, -19097.3), Valid Lower Bound: -19947.6
# Processing epoch: 169/1000
# EPOCH: 00169, Train Lower Bound: -19163.9, (-60.0, -19103.9), Valid Lower Bound: -19936.0
# Processing epoch: 170/1000
# EPOCH: 00170, Train Lower Bound: -19145.9, (-60.3, -19085.6), Valid Lower Bound: -19962.7
# Processing epoch: 171/1000
# EPOCH: 00171, Train Lower Bound: -19163.6, (-60.4, -19103.2), Valid Lower Bound: -19998.7
# Processing epoch: 172/1000
# EPOCH: 00172, Train Lower Bound: -19186.8, (-59.8, -19127.0), Valid Lower Bound: -19940.6
# Processing epoch: 173/1000
# EPOCH: 00173, Train Lower Bound: -19139.7, (-60.4, -19079.3), Valid Lower Bound: -19950.3
# Processing epoch: 174/1000
# EPOCH: 00174, Train Lower Bound: -19121.2, (-60.7, -19060.5), Valid Lower Bound: -19972.2
# Processing epoch: 175/1000
# EPOCH: 00175, Train Lower Bound: -19126.7, (-60.7, -19066.0), Valid Lower Bound: -19942.2
# Processing epoch: 176/1000
# EPOCH: 00176, Train Lower Bound: -19118.5, (-61.0, -19057.5), Valid Lower Bound: -19951.4
# Processing epoch: 177/1000
# EPOCH: 00177, Train Lower Bound: -19125.3, (-60.6, -19064.7), Valid Lower Bound: -19950.8
# Processing epoch: 178/1000
# EPOCH: 00178, Train Lower Bound: -19119.4, (-60.7, -19058.7), Valid Lower Bound: -19981.1
# Processing epoch: 179/1000
# EPOCH: 00179, Train Lower Bound: -19105.8, (-60.9, -19044.9), Valid Lower Bound: -19951.2
# Processing epoch: 180/1000
# EPOCH: 00180, Train Lower Bound: -19100.0, (-61.0, -19039.0), Valid Lower Bound: -19935.7
# Processing epoch: 181/1000
# EPOCH: 00181, Train Lower Bound: -19099.8, (-61.0, -19038.8), Valid Lower Bound: -19956.1
# Processing epoch: 182/1000
# EPOCH: 00182, Train Lower Bound: -19088.5, (-61.4, -19027.1), Valid Lower Bound: -19931.8
# Processing epoch: 183/1000
# EPOCH: 00183, Train Lower Bound: -19089.8, (-61.2, -19028.7), Valid Lower Bound: -19984.5
# Processing epoch: 184/1000
# EPOCH: 00184, Train Lower Bound: -19084.6, (-61.1, -19023.4), Valid Lower Bound: -19967.4
# Processing epoch: 185/1000
# EPOCH: 00185, Train Lower Bound: -19080.4, (-61.2, -19019.2), Valid Lower Bound: -19948.9
# Processing epoch: 186/1000
# EPOCH: 00186, Train Lower Bound: -19075.2, (-61.2, -19014.0), Valid Lower Bound: -19975.4
# Processing epoch: 187/1000
# EPOCH: 00187, Train Lower Bound: -19059.5, (-61.8, -18997.7), Valid Lower Bound: -19951.8
# Processing epoch: 188/1000
# EPOCH: 00188, Train Lower Bound: -19057.4, (-61.7, -18995.8), Valid Lower Bound: -19982.7
# Processing epoch: 189/1000
# EPOCH: 00189, Train Lower Bound: -19051.4, (-61.7, -18989.7), Valid Lower Bound: -19970.1
# Processing epoch: 190/1000
# EPOCH: 00190, Train Lower Bound: -19059.0, (-61.7, -18997.3), Valid Lower Bound: -19970.6
# Processing epoch: 191/1000
# EPOCH: 00191, Train Lower Bound: -19054.0, (-61.7, -18992.3), Valid Lower Bound: -20004.5
# Processing epoch: 192/1000
# EPOCH: 00192, Train Lower Bound: -19047.6, (-61.9, -18985.7), Valid Lower Bound: -19974.6
# Processing epoch: 193/1000
# EPOCH: 00193, Train Lower Bound: -19041.2, (-61.8, -18979.4), Valid Lower Bound: -19957.2
# Processing epoch: 194/1000
# EPOCH: 00194, Train Lower Bound: -19027.2, (-62.1, -18965.1), Valid Lower Bound: -19968.0
# Processing epoch: 195/1000
# EPOCH: 00195, Train Lower Bound: -19024.5, (-62.1, -18962.4), Valid Lower Bound: -20012.0
# Processing epoch: 196/1000
# EPOCH: 00196, Train Lower Bound: -19032.8, (-62.2, -18970.6), Valid Lower Bound: -20009.7
# Processing epoch: 197/1000
# EPOCH: 00197, Train Lower Bound: -19013.8, (-62.2, -18951.7), Valid Lower Bound: -20007.2
# Processing epoch: 198/1000
# EPOCH: 00198, Train Lower Bound: -19004.1, (-62.4, -18941.7), Valid Lower Bound: -19997.1
# Processing epoch: 199/1000
# EPOCH: 00199, Train Lower Bound: -19002.9, (-62.4, -18940.5), Valid Lower Bound: -19983.9
# Processing epoch: 200/1000
# EPOCH: 00200, Train Lower Bound: -18996.3, (-62.7, -18933.6), Valid Lower Bound: -20020.3
# Processing epoch: 201/1000
# EPOCH: 00201, Train Lower Bound: -19002.0, (-62.5, -18939.5), Valid Lower Bound: -20027.9
# Processing epoch: 202/1000
# EPOCH: 00202, Train Lower Bound: -18997.5, (-62.7, -18934.8), Valid Lower Bound: -20027.0
# Processing epoch: 203/1000
# EPOCH: 00203, Train Lower Bound: -18988.1, (-62.6, -18925.5), Valid Lower Bound: -20015.6
# Processing epoch: 204/1000
# EPOCH: 00204, Train Lower Bound: -18991.5, (-62.7, -18928.7), Valid Lower Bound: -20020.0
# Processing epoch: 205/1000
# EPOCH: 00205, Train Lower Bound: -18977.0, (-62.9, -18914.1), Valid Lower Bound: -20029.6
# Processing epoch: 206/1000
# EPOCH: 00206, Train Lower Bound: -18971.6, (-62.9, -18908.7), Valid Lower Bound: -20030.7
# Processing epoch: 207/1000
# EPOCH: 00207, Train Lower Bound: -18972.6, (-63.0, -18909.6), Valid Lower Bound: -20039.4
# Processing epoch: 208/1000
# EPOCH: 00208, Train Lower Bound: -18977.6, (-62.9, -18914.6), Valid Lower Bound: -20017.9
# Processing epoch: 209/1000
# EPOCH: 00209, Train Lower Bound: -18959.7, (-63.2, -18896.5), Valid Lower Bound: -20049.6
# Processing epoch: 210/1000
# EPOCH: 00210, Train Lower Bound: -18952.9, (-63.4, -18889.6), Valid Lower Bound: -20027.2
# Processing epoch: 211/1000
# EPOCH: 00211, Train Lower Bound: -18961.0, (-63.1, -18897.9), Valid Lower Bound: -20006.5
# Processing epoch: 212/1000
# EPOCH: 00212, Train Lower Bound: -18946.0, (-63.5, -18882.6), Valid Lower Bound: -20030.9
# Processing epoch: 213/1000
# EPOCH: 00213, Train Lower Bound: -18952.5, (-63.2, -18889.3), Valid Lower Bound: -20044.7
# Processing epoch: 214/1000
# EPOCH: 00214, Train Lower Bound: -18936.1, (-63.8, -18872.3), Valid Lower Bound: -20015.2
# Processing epoch: 215/1000
# EPOCH: 00215, Train Lower Bound: -18927.1, (-63.7, -18863.4), Valid Lower Bound: -20048.3
# Processing epoch: 216/1000
# EPOCH: 00216, Train Lower Bound: -18942.4, (-63.7, -18878.7), Valid Lower Bound: -20042.2
# Processing epoch: 217/1000
# EPOCH: 00217, Train Lower Bound: -18922.2, (-63.9, -18858.3), Valid Lower Bound: -20039.6
# Processing epoch: 218/1000
# EPOCH: 00218, Train Lower Bound: -18913.8, (-64.1, -18849.6), Valid Lower Bound: -20026.8
# Processing epoch: 219/1000
# EPOCH: 00219, Train Lower Bound: -18905.7, (-64.3, -18841.4), Valid Lower Bound: -20039.0
# Processing epoch: 220/1000
# EPOCH: 00220, Train Lower Bound: -18901.9, (-64.3, -18837.6), Valid Lower Bound: -20013.3
# Processing epoch: 221/1000
# EPOCH: 00221, Train Lower Bound: -18899.7, (-64.4, -18835.3), Valid Lower Bound: -20051.0
# Processing epoch: 222/1000
# EPOCH: 00222, Train Lower Bound: -18903.9, (-64.1, -18839.8), Valid Lower Bound: -20020.8
# Processing epoch: 223/1000
# EPOCH: 00223, Train Lower Bound: -18912.9, (-64.2, -18848.7), Valid Lower Bound: -20064.2
# Processing epoch: 224/1000
# EPOCH: 00224, Train Lower Bound: -18896.6, (-64.5, -18832.1), Valid Lower Bound: -20069.3
# Processing epoch: 225/1000
# EPOCH: 00225, Train Lower Bound: -18885.2, (-64.7, -18820.6), Valid Lower Bound: -20062.1
# Processing epoch: 226/1000
# EPOCH: 00226, Train Lower Bound: -18875.7, (-64.8, -18810.9), Valid Lower Bound: -20036.7
# Processing epoch: 227/1000
# EPOCH: 00227, Train Lower Bound: -18876.6, (-64.9, -18811.7), Valid Lower Bound: -20089.6
# Processing epoch: 228/1000
# EPOCH: 00228, Train Lower Bound: -18872.6, (-65.0, -18807.6), Valid Lower Bound: -20078.6
# Processing epoch: 229/1000
# EPOCH: 00229, Train Lower Bound: -18866.3, (-65.0, -18801.3), Valid Lower Bound: -20080.3
# Processing epoch: 230/1000
# EPOCH: 00230, Train Lower Bound: -18854.3, (-65.2, -18789.1), Valid Lower Bound: -20087.5
# Processing epoch: 231/1000
# EPOCH: 00231, Train Lower Bound: -18855.1, (-65.3, -18789.8), Valid Lower Bound: -20060.4
# Processing epoch: 232/1000
# EPOCH: 00232, Train Lower Bound: -18868.8, (-64.9, -18803.8), Valid Lower Bound: -20108.4
# Processing epoch: 233/1000
# EPOCH: 00233, Train Lower Bound: -18861.4, (-64.9, -18796.5), Valid Lower Bound: -20080.0
# Processing epoch: 234/1000
# EPOCH: 00234, Train Lower Bound: -18845.6, (-65.4, -18780.1), Valid Lower Bound: -20076.0
# Processing epoch: 235/1000
# EPOCH: 00235, Train Lower Bound: -18834.3, (-65.5, -18768.8), Valid Lower Bound: -20065.8
# Processing epoch: 236/1000
# EPOCH: 00236, Train Lower Bound: -18827.8, (-65.9, -18761.9), Valid Lower Bound: -20125.1
# Processing epoch: 237/1000
# EPOCH: 00237, Train Lower Bound: -18822.4, (-65.9, -18756.6), Valid Lower Bound: -20100.2
# Processing epoch: 238/1000
# EPOCH: 00238, Train Lower Bound: -18823.3, (-66.0, -18757.4), Valid Lower Bound: -20104.5
# Processing epoch: 239/1000
# EPOCH: 00239, Train Lower Bound: -18814.7, (-66.1, -18748.7), Valid Lower Bound: -20111.3
# Processing epoch: 240/1000
# EPOCH: 00240, Train Lower Bound: -18813.7, (-66.0, -18747.7), Valid Lower Bound: -20106.6
# Processing epoch: 241/1000
# EPOCH: 00241, Train Lower Bound: -18811.0, (-66.3, -18744.7), Valid Lower Bound: -20081.2
# Processing epoch: 242/1000
# EPOCH: 00242, Train Lower Bound: -18805.2, (-66.1, -18739.1), Valid Lower Bound: -20113.7
# Processing epoch: 243/1000
# EPOCH: 00243, Train Lower Bound: -18805.5, (-66.4, -18739.1), Valid Lower Bound: -20095.6
# Processing epoch: 244/1000
# EPOCH: 00244, Train Lower Bound: -18797.2, (-66.4, -18730.8), Valid Lower Bound: -20122.5
# Processing epoch: 245/1000
# EPOCH: 00245, Train Lower Bound: -18790.6, (-66.4, -18724.2), Valid Lower Bound: -20123.7
# Processing epoch: 246/1000
# EPOCH: 00246, Train Lower Bound: -18788.8, (-66.5, -18722.2), Valid Lower Bound: -20084.9
# Processing epoch: 247/1000
# EPOCH: 00247, Train Lower Bound: -18792.2, (-66.4, -18725.8), Valid Lower Bound: -20151.4
# Processing epoch: 248/1000
# EPOCH: 00248, Train Lower Bound: -18780.2, (-66.7, -18713.5), Valid Lower Bound: -20102.4
# Processing epoch: 249/1000
# EPOCH: 00249, Train Lower Bound: -18778.7, (-66.7, -18712.0), Valid Lower Bound: -20127.6
# Processing epoch: 250/1000
# EPOCH: 00250, Train Lower Bound: -18766.1, (-67.0, -18699.2), Valid Lower Bound: -20109.0
# Processing epoch: 251/1000
# EPOCH: 00251, Train Lower Bound: -18765.5, (-66.9, -18698.7), Valid Lower Bound: -20175.3
# Processing epoch: 252/1000
# EPOCH: 00252, Train Lower Bound: -18755.2, (-67.0, -18688.2), Valid Lower Bound: -20098.6
# Processing epoch: 253/1000
# EPOCH: 00253, Train Lower Bound: -18760.5, (-67.2, -18693.3), Valid Lower Bound: -20130.9
# Processing epoch: 254/1000
# EPOCH: 00254, Train Lower Bound: -18749.5, (-67.2, -18682.3), Valid Lower Bound: -20137.6
# Processing epoch: 255/1000
# EPOCH: 00255, Train Lower Bound: -18743.2, (-67.4, -18675.7), Valid Lower Bound: -20131.5
# Processing epoch: 256/1000
# EPOCH: 00256, Train Lower Bound: -18741.2, (-67.2, -18674.0), Valid Lower Bound: -20137.2
# Processing epoch: 257/1000
# EPOCH: 00257, Train Lower Bound: -18735.7, (-67.4, -18668.4), Valid Lower Bound: -20122.9
# Processing epoch: 258/1000
# EPOCH: 00258, Train Lower Bound: -18749.5, (-67.2, -18682.2), Valid Lower Bound: -20172.8
# Processing epoch: 259/1000
# EPOCH: 00259, Train Lower Bound: -18729.5, (-67.7, -18661.8), Valid Lower Bound: -20166.7
# Processing epoch: 260/1000
# EPOCH: 00260, Train Lower Bound: -18725.8, (-67.7, -18658.1), Valid Lower Bound: -20181.0
# Processing epoch: 261/1000
# EPOCH: 00261, Train Lower Bound: -18732.6, (-67.4, -18665.2), Valid Lower Bound: -20132.4
# Processing epoch: 262/1000
# EPOCH: 00262, Train Lower Bound: -18721.3, (-67.8, -18653.5), Valid Lower Bound: -20159.3
# Processing epoch: 263/1000
# EPOCH: 00263, Train Lower Bound: -18715.4, (-67.9, -18647.5), Valid Lower Bound: -20195.5
# Processing epoch: 264/1000
# EPOCH: 00264, Train Lower Bound: -18702.1, (-68.3, -18633.8), Valid Lower Bound: -20159.3
# Processing epoch: 265/1000
# EPOCH: 00265, Train Lower Bound: -18705.6, (-68.1, -18637.6), Valid Lower Bound: -20155.6
# Processing epoch: 266/1000
# EPOCH: 00266, Train Lower Bound: -18693.6, (-68.2, -18625.4), Valid Lower Bound: -20183.2
# Processing epoch: 267/1000
# EPOCH: 00267, Train Lower Bound: -18692.2, (-68.3, -18624.0), Valid Lower Bound: -20152.2
# Processing epoch: 268/1000
# EPOCH: 00268, Train Lower Bound: -18703.1, (-68.1, -18635.0), Valid Lower Bound: -20165.3
# Processing epoch: 269/1000
# EPOCH: 00269, Train Lower Bound: -18681.0, (-68.6, -18612.4), Valid Lower Bound: -20175.6
# Processing epoch: 270/1000
# EPOCH: 00270, Train Lower Bound: -18679.7, (-68.6, -18611.2), Valid Lower Bound: -20175.2
# Processing epoch: 271/1000
# EPOCH: 00271, Train Lower Bound: -18679.8, (-68.8, -18611.1), Valid Lower Bound: -20155.6
# Processing epoch: 272/1000
# EPOCH: 00272, Train Lower Bound: -18673.0, (-68.8, -18604.2), Valid Lower Bound: -20180.1
# Processing epoch: 273/1000
# EPOCH: 00273, Train Lower Bound: -18664.7, (-69.0, -18595.8), Valid Lower Bound: -20187.9
# Processing epoch: 274/1000
# EPOCH: 00274, Train Lower Bound: -18660.1, (-68.9, -18591.2), Valid Lower Bound: -20200.6
# Processing epoch: 275/1000
# EPOCH: 00275, Train Lower Bound: -18667.2, (-68.9, -18598.2), Valid Lower Bound: -20225.3
# Processing epoch: 276/1000
# EPOCH: 00276, Train Lower Bound: -18658.6, (-68.9, -18589.8), Valid Lower Bound: -20203.6
# Processing epoch: 277/1000
# EPOCH: 00277, Train Lower Bound: -18656.0, (-69.1, -18586.9), Valid Lower Bound: -20193.8
# Processing epoch: 278/1000
# EPOCH: 00278, Train Lower Bound: -18660.2, (-68.9, -18591.2), Valid Lower Bound: -20183.4
# Processing epoch: 279/1000
# EPOCH: 00279, Train Lower Bound: -18654.1, (-68.8, -18585.4), Valid Lower Bound: -20243.7
# Processing epoch: 280/1000
# EPOCH: 00280, Train Lower Bound: -18638.6, (-69.2, -18569.4), Valid Lower Bound: -20224.2
# Processing epoch: 281/1000
# EPOCH: 00281, Train Lower Bound: -18627.9, (-69.6, -18558.3), Valid Lower Bound: -20239.4
# Processing epoch: 282/1000
# EPOCH: 00282, Train Lower Bound: -18643.9, (-69.4, -18574.5), Valid Lower Bound: -20200.4
# Processing epoch: 283/1000
# EPOCH: 00283, Train Lower Bound: -18625.1, (-69.7, -18555.4), Valid Lower Bound: -20200.2
# Processing epoch: 284/1000
# EPOCH: 00284, Train Lower Bound: -18616.5, (-69.8, -18546.7), Valid Lower Bound: -20213.5
# Processing epoch: 285/1000
# EPOCH: 00285, Train Lower Bound: -18609.2, (-69.9, -18539.3), Valid Lower Bound: -20249.8
# Processing epoch: 286/1000
# EPOCH: 00286, Train Lower Bound: -18610.8, (-70.1, -18540.7), Valid Lower Bound: -20210.9
# Processing epoch: 287/1000
# EPOCH: 00287, Train Lower Bound: -18613.3, (-69.9, -18543.4), Valid Lower Bound: -20226.8
# Processing epoch: 288/1000
# EPOCH: 00288, Train Lower Bound: -18613.9, (-69.8, -18544.1), Valid Lower Bound: -20236.9
# Processing epoch: 289/1000
# EPOCH: 00289, Train Lower Bound: -18605.9, (-69.9, -18535.9), Valid Lower Bound: -20251.5
# Processing epoch: 290/1000
# EPOCH: 00290, Train Lower Bound: -18600.8, (-70.0, -18530.7), Valid Lower Bound: -20259.5
# Processing epoch: 291/1000
# EPOCH: 00291, Train Lower Bound: -18588.8, (-70.4, -18518.4), Valid Lower Bound: -20228.7
# Processing epoch: 292/1000
# EPOCH: 00292, Train Lower Bound: -18586.4, (-70.2, -18516.2), Valid Lower Bound: -20235.1
# Processing epoch: 293/1000
# EPOCH: 00293, Train Lower Bound: -18579.2, (-70.5, -18508.7), Valid Lower Bound: -20249.3
# Processing epoch: 294/1000
# EPOCH: 00294, Train Lower Bound: -18585.7, (-70.3, -18515.4), Valid Lower Bound: -20252.8
# Processing epoch: 295/1000
# EPOCH: 00295, Train Lower Bound: -18596.7, (-70.0, -18526.8), Valid Lower Bound: -20272.4
# Processing epoch: 296/1000
# EPOCH: 00296, Train Lower Bound: -18578.5, (-70.4, -18508.1), Valid Lower Bound: -20225.1
# Processing epoch: 297/1000
# EPOCH: 00297, Train Lower Bound: -18572.3, (-70.6, -18501.8), Valid Lower Bound: -20228.2
# Processing epoch: 298/1000
# EPOCH: 00298, Train Lower Bound: -18562.1, (-70.8, -18491.3), Valid Lower Bound: -20261.3
# Processing epoch: 299/1000
# EPOCH: 00299, Train Lower Bound: -18553.9, (-71.0, -18482.9), Valid Lower Bound: -20229.8
# Processing epoch: 300/1000
# EPOCH: 00300, Train Lower Bound: -18541.9, (-71.3, -18470.6), Valid Lower Bound: -20254.5
# Processing epoch: 301/1000
# EPOCH: 00301, Train Lower Bound: -18547.9, (-71.1, -18476.9), Valid Lower Bound: -20292.2
# Processing epoch: 302/1000
# EPOCH: 00302, Train Lower Bound: -18549.9, (-70.9, -18479.0), Valid Lower Bound: -20282.6
# Processing epoch: 303/1000
# EPOCH: 00303, Train Lower Bound: -18543.5, (-71.3, -18472.2), Valid Lower Bound: -20236.8
# Processing epoch: 304/1000
# EPOCH: 00304, Train Lower Bound: -18545.0, (-71.0, -18474.0), Valid Lower Bound: -20257.5
# Processing epoch: 305/1000
# EPOCH: 00305, Train Lower Bound: -18542.7, (-71.1, -18471.6), Valid Lower Bound: -20258.8
# Processing epoch: 306/1000
# EPOCH: 00306, Train Lower Bound: -18531.1, (-71.4, -18459.7), Valid Lower Bound: -20251.2
# Processing epoch: 307/1000
# EPOCH: 00307, Train Lower Bound: -18538.1, (-71.1, -18467.0), Valid Lower Bound: -20271.0
# Processing epoch: 308/1000
# EPOCH: 00308, Train Lower Bound: -18547.3, (-71.0, -18476.4), Valid Lower Bound: -20283.3
# Processing epoch: 309/1000
# EPOCH: 00309, Train Lower Bound: -18520.0, (-71.4, -18448.6), Valid Lower Bound: -20320.9
# Processing epoch: 310/1000
# EPOCH: 00310, Train Lower Bound: -18512.4, (-71.5, -18440.9), Valid Lower Bound: -20329.1
# Processing epoch: 311/1000
# EPOCH: 00311, Train Lower Bound: -18515.8, (-71.6, -18444.3), Valid Lower Bound: -20287.6
# Processing epoch: 312/1000
# EPOCH: 00312, Train Lower Bound: -18505.8, (-71.8, -18433.9), Valid Lower Bound: -20333.0
# Processing epoch: 313/1000
# EPOCH: 00313, Train Lower Bound: -18510.0, (-71.8, -18438.2), Valid Lower Bound: -20266.6
# Processing epoch: 314/1000
# EPOCH: 00314, Train Lower Bound: -18498.8, (-72.0, -18426.8), Valid Lower Bound: -20298.9
# Processing epoch: 315/1000
# EPOCH: 00315, Train Lower Bound: -18489.0, (-72.0, -18416.9), Valid Lower Bound: -20322.2
# Processing epoch: 316/1000
# EPOCH: 00316, Train Lower Bound: -18488.2, (-72.1, -18416.1), Valid Lower Bound: -20302.0
# Processing epoch: 317/1000
# EPOCH: 00317, Train Lower Bound: -18484.3, (-72.1, -18412.1), Valid Lower Bound: -20305.3
# Processing epoch: 318/1000
# EPOCH: 00318, Train Lower Bound: -18486.7, (-72.3, -18414.4), Valid Lower Bound: -20305.0
# Processing epoch: 319/1000
# EPOCH: 00319, Train Lower Bound: -18491.9, (-71.8, -18420.1), Valid Lower Bound: -20371.7
# Processing epoch: 320/1000
# EPOCH: 00320, Train Lower Bound: -18496.6, (-71.8, -18424.8), Valid Lower Bound: -20343.9
# Processing epoch: 321/1000
# EPOCH: 00321, Train Lower Bound: -18479.5, (-72.1, -18407.4), Valid Lower Bound: -20303.1
# Processing epoch: 322/1000
# EPOCH: 00322, Train Lower Bound: -18474.2, (-72.2, -18402.0), Valid Lower Bound: -20329.3
# Processing epoch: 323/1000
# EPOCH: 00323, Train Lower Bound: -18477.1, (-72.2, -18404.9), Valid Lower Bound: -20313.8
# Processing epoch: 324/1000
# EPOCH: 00324, Train Lower Bound: -18473.3, (-72.2, -18401.1), Valid Lower Bound: -20321.5
# Processing epoch: 325/1000
# EPOCH: 00325, Train Lower Bound: -18472.5, (-72.1, -18400.4), Valid Lower Bound: -20385.1
# Processing epoch: 326/1000
# EPOCH: 00326, Train Lower Bound: -18454.2, (-72.6, -18381.6), Valid Lower Bound: -20317.6
# Processing epoch: 327/1000
# EPOCH: 00327, Train Lower Bound: -18440.7, (-72.9, -18367.7), Valid Lower Bound: -20325.8
# Processing epoch: 328/1000
# EPOCH: 00328, Train Lower Bound: -18442.9, (-72.8, -18370.1), Valid Lower Bound: -20304.0
# Processing epoch: 329/1000
# EPOCH: 00329, Train Lower Bound: -18435.0, (-72.8, -18362.2), Valid Lower Bound: -20388.6
# Processing epoch: 330/1000
# EPOCH: 00330, Train Lower Bound: -18442.3, (-72.7, -18369.6), Valid Lower Bound: -20292.3
# Processing epoch: 331/1000
# EPOCH: 00331, Train Lower Bound: -18438.1, (-73.0, -18365.1), Valid Lower Bound: -20346.7
# Processing epoch: 332/1000
# EPOCH: 00332, Train Lower Bound: -18441.0, (-72.9, -18368.1), Valid Lower Bound: -20341.7
# Processing epoch: 333/1000
# EPOCH: 00333, Train Lower Bound: -18432.4, (-72.7, -18359.7), Valid Lower Bound: -20337.0
# Processing epoch: 334/1000
# EPOCH: 00334, Train Lower Bound: -18421.1, (-73.0, -18348.0), Valid Lower Bound: -20339.0
# Processing epoch: 335/1000
# EPOCH: 00335, Train Lower Bound: -18422.3, (-73.2, -18349.1), Valid Lower Bound: -20374.3
# Processing epoch: 336/1000
# EPOCH: 00336, Train Lower Bound: -18416.6, (-73.3, -18343.3), Valid Lower Bound: -20355.7
# Processing epoch: 337/1000
# EPOCH: 00337, Train Lower Bound: -18424.1, (-73.1, -18350.9), Valid Lower Bound: -20415.2
# Processing epoch: 338/1000
# EPOCH: 00338, Train Lower Bound: -18413.8, (-73.3, -18340.5), Valid Lower Bound: -20361.7
# Processing epoch: 339/1000
# EPOCH: 00339, Train Lower Bound: -18401.3, (-73.5, -18327.8), Valid Lower Bound: -20365.9
# Processing epoch: 340/1000
# EPOCH: 00340, Train Lower Bound: -18403.1, (-73.5, -18329.6), Valid Lower Bound: -20380.4
# Processing epoch: 341/1000
# EPOCH: 00341, Train Lower Bound: -18399.8, (-73.6, -18326.2), Valid Lower Bound: -20375.3
# Processing epoch: 342/1000
# EPOCH: 00342, Train Lower Bound: -18420.9, (-73.3, -18347.6), Valid Lower Bound: -20331.8
# Processing epoch: 343/1000
# EPOCH: 00343, Train Lower Bound: -18413.0, (-73.1, -18339.9), Valid Lower Bound: -20362.3
# Processing epoch: 344/1000
# EPOCH: 00344, Train Lower Bound: -18400.9, (-73.4, -18327.5), Valid Lower Bound: -20409.3
# Processing epoch: 345/1000
# EPOCH: 00345, Train Lower Bound: -18382.9, (-73.7, -18309.2), Valid Lower Bound: -20368.3
# Processing epoch: 346/1000
# EPOCH: 00346, Train Lower Bound: -18380.9, (-73.7, -18307.1), Valid Lower Bound: -20390.4
# Processing epoch: 347/1000
# EPOCH: 00347, Train Lower Bound: -18372.7, (-73.9, -18298.8), Valid Lower Bound: -20391.1
# Processing epoch: 348/1000
# EPOCH: 00348, Train Lower Bound: -18371.1, (-74.3, -18296.8), Valid Lower Bound: -20425.8
# Processing epoch: 349/1000
# EPOCH: 00349, Train Lower Bound: -18369.7, (-74.0, -18295.7), Valid Lower Bound: -20382.4
# Processing epoch: 350/1000
# EPOCH: 00350, Train Lower Bound: -18369.6, (-74.1, -18295.5), Valid Lower Bound: -20378.7
# Processing epoch: 351/1000
# EPOCH: 00351, Train Lower Bound: -18373.4, (-73.9, -18299.5), Valid Lower Bound: -20463.9
# Processing epoch: 352/1000
# EPOCH: 00352, Train Lower Bound: -18362.3, (-74.0, -18288.3), Valid Lower Bound: -20412.0
# Processing epoch: 353/1000
# EPOCH: 00353, Train Lower Bound: -18352.8, (-74.3, -18278.4), Valid Lower Bound: -20395.5
# Processing epoch: 354/1000
# EPOCH: 00354, Train Lower Bound: -18353.2, (-74.3, -18278.9), Valid Lower Bound: -20433.7
# Processing epoch: 355/1000
# EPOCH: 00355, Train Lower Bound: -18350.3, (-74.5, -18275.8), Valid Lower Bound: -20436.6
# Processing epoch: 356/1000
# EPOCH: 00356, Train Lower Bound: -18346.4, (-74.4, -18272.0), Valid Lower Bound: -20420.7
# Processing epoch: 357/1000
# EPOCH: 00357, Train Lower Bound: -18342.4, (-74.6, -18267.8), Valid Lower Bound: -20394.7
# Processing epoch: 358/1000
# EPOCH: 00358, Train Lower Bound: -18344.3, (-74.6, -18269.7), Valid Lower Bound: -20447.9
# Processing epoch: 359/1000
# EPOCH: 00359, Train Lower Bound: -18337.8, (-74.7, -18263.1), Valid Lower Bound: -20418.8
# Processing epoch: 360/1000
# EPOCH: 00360, Train Lower Bound: -18341.1, (-74.5, -18266.6), Valid Lower Bound: -20434.6
# Processing epoch: 361/1000
# EPOCH: 00361, Train Lower Bound: -18333.5, (-74.8, -18258.7), Valid Lower Bound: -20489.6
# Processing epoch: 362/1000
# EPOCH: 00362, Train Lower Bound: -18323.5, (-75.0, -18248.5), Valid Lower Bound: -20402.8
# Processing epoch: 363/1000
# EPOCH: 00363, Train Lower Bound: -18322.3, (-75.1, -18247.2), Valid Lower Bound: -20469.8
# Processing epoch: 364/1000
# EPOCH: 00364, Train Lower Bound: -18319.5, (-75.1, -18244.4), Valid Lower Bound: -20435.8
# Processing epoch: 365/1000
# EPOCH: 00365, Train Lower Bound: -18322.3, (-74.6, -18247.6), Valid Lower Bound: -20586.1
# Processing epoch: 366/1000
# EPOCH: 00366, Train Lower Bound: -18318.5, (-74.9, -18243.6), Valid Lower Bound: -20449.7
# Processing epoch: 367/1000
# EPOCH: 00367, Train Lower Bound: -18311.5, (-75.1, -18236.3), Valid Lower Bound: -20443.2
# Processing epoch: 368/1000
# EPOCH: 00368, Train Lower Bound: -18307.1, (-75.2, -18231.9), Valid Lower Bound: -20466.0
# Processing epoch: 369/1000
# EPOCH: 00369, Train Lower Bound: -18302.3, (-75.3, -18227.0), Valid Lower Bound: -20474.8
# Processing epoch: 370/1000
# EPOCH: 00370, Train Lower Bound: -18312.8, (-75.2, -18237.6), Valid Lower Bound: -20469.9
# Processing epoch: 371/1000
# EPOCH: 00371, Train Lower Bound: -18297.8, (-75.3, -18222.5), Valid Lower Bound: -20433.5
# Processing epoch: 372/1000
# EPOCH: 00372, Train Lower Bound: -18297.7, (-75.2, -18222.5), Valid Lower Bound: -20464.4
# Processing epoch: 373/1000
# EPOCH: 00373, Train Lower Bound: -18290.0, (-75.5, -18214.5), Valid Lower Bound: -20497.3
# Processing epoch: 374/1000
# EPOCH: 00374, Train Lower Bound: -18285.3, (-75.5, -18209.7), Valid Lower Bound: -20483.6
# Processing epoch: 375/1000
# EPOCH: 00375, Train Lower Bound: -18286.1, (-75.5, -18210.6), Valid Lower Bound: -20454.3
# Processing epoch: 376/1000
# EPOCH: 00376, Train Lower Bound: -18282.7, (-75.7, -18207.0), Valid Lower Bound: -20400.2
# Processing epoch: 377/1000
# EPOCH: 00377, Train Lower Bound: -18313.1, (-74.9, -18238.2), Valid Lower Bound: -20450.3
# Processing epoch: 378/1000
# EPOCH: 00378, Train Lower Bound: -18279.1, (-75.3, -18203.7), Valid Lower Bound: -20512.2
# Processing epoch: 379/1000
# EPOCH: 00379, Train Lower Bound: -18270.6, (-75.6, -18195.1), Valid Lower Bound: -20497.1
# Processing epoch: 380/1000
# EPOCH: 00380, Train Lower Bound: -18260.2, (-75.8, -18184.4), Valid Lower Bound: -20525.6
# Processing epoch: 381/1000
# EPOCH: 00381, Train Lower Bound: -18254.7, (-76.2, -18178.5), Valid Lower Bound: -20522.1
# Processing epoch: 382/1000
# EPOCH: 00382, Train Lower Bound: -18250.4, (-76.1, -18174.3), Valid Lower Bound: -20480.9
# Processing epoch: 383/1000
# EPOCH: 00383, Train Lower Bound: -18252.7, (-76.2, -18176.5), Valid Lower Bound: -20497.5
# Processing epoch: 384/1000
# EPOCH: 00384, Train Lower Bound: -18243.2, (-76.3, -18166.8), Valid Lower Bound: -20533.3
# Processing epoch: 385/1000
# EPOCH: 00385, Train Lower Bound: -18241.4, (-76.4, -18165.0), Valid Lower Bound: -20519.9
# Processing epoch: 386/1000
# EPOCH: 00386, Train Lower Bound: -18246.7, (-76.2, -18170.4), Valid Lower Bound: -20504.6
# Processing epoch: 387/1000
# EPOCH: 00387, Train Lower Bound: -18256.0, (-76.2, -18179.8), Valid Lower Bound: -20538.0
# Processing epoch: 388/1000
# EPOCH: 00388, Train Lower Bound: -18243.0, (-76.2, -18166.8), Valid Lower Bound: -20528.4
# Processing epoch: 389/1000
# EPOCH: 00389, Train Lower Bound: -18240.1, (-76.5, -18163.7), Valid Lower Bound: -20491.8
# Processing epoch: 390/1000
# EPOCH: 00390, Train Lower Bound: -18243.6, (-76.2, -18167.4), Valid Lower Bound: -20516.1
# Processing epoch: 391/1000
# EPOCH: 00391, Train Lower Bound: -18240.0, (-76.3, -18163.7), Valid Lower Bound: -20526.7
# Processing epoch: 392/1000
# EPOCH: 00392, Train Lower Bound: -18222.7, (-76.6, -18146.1), Valid Lower Bound: -20493.5
# Processing epoch: 393/1000
# EPOCH: 00393, Train Lower Bound: -18216.1, (-76.7, -18139.4), Valid Lower Bound: -20555.5
# Processing epoch: 394/1000
# EPOCH: 00394, Train Lower Bound: -18212.1, (-76.8, -18135.2), Valid Lower Bound: -20524.3
# Processing epoch: 395/1000
# EPOCH: 00395, Train Lower Bound: -18211.5, (-76.9, -18134.5), Valid Lower Bound: -20540.7
# Processing epoch: 396/1000
# EPOCH: 00396, Train Lower Bound: -18211.7, (-76.8, -18134.9), Valid Lower Bound: -20556.4
# Processing epoch: 397/1000
# EPOCH: 00397, Train Lower Bound: -18208.4, (-77.0, -18131.5), Valid Lower Bound: -20489.6
# Processing epoch: 398/1000
# EPOCH: 00398, Train Lower Bound: -18209.3, (-76.8, -18132.6), Valid Lower Bound: -20558.2
# Processing epoch: 399/1000
# EPOCH: 00399, Train Lower Bound: -18214.4, (-76.8, -18137.6), Valid Lower Bound: -20541.7
# Processing epoch: 400/1000
# EPOCH: 00400, Train Lower Bound: -18209.2, (-77.0, -18132.2), Valid Lower Bound: -20530.6
# Processing epoch: 401/1000
# EPOCH: 00401, Train Lower Bound: -18197.2, (-77.1, -18120.1), Valid Lower Bound: -20534.8
# Processing epoch: 402/1000
# EPOCH: 00402, Train Lower Bound: -18195.4, (-77.2, -18118.2), Valid Lower Bound: -20558.5
# Processing epoch: 403/1000
# EPOCH: 00403, Train Lower Bound: -18188.6, (-77.2, -18111.4), Valid Lower Bound: -20552.7
# Processing epoch: 404/1000
# EPOCH: 00404, Train Lower Bound: -18191.1, (-77.1, -18114.0), Valid Lower Bound: -20576.5
# Processing epoch: 405/1000
# EPOCH: 00405, Train Lower Bound: -18192.0, (-77.1, -18115.0), Valid Lower Bound: -20534.5
# Processing epoch: 406/1000
# EPOCH: 00406, Train Lower Bound: -18185.3, (-77.5, -18107.8), Valid Lower Bound: -20584.9
# Processing epoch: 407/1000
# EPOCH: 00407, Train Lower Bound: -18177.1, (-77.5, -18099.6), Valid Lower Bound: -20572.1
# Processing epoch: 408/1000
# EPOCH: 00408, Train Lower Bound: -18171.6, (-77.5, -18094.2), Valid Lower Bound: -20560.2
# Processing epoch: 409/1000
# EPOCH: 00409, Train Lower Bound: -18166.9, (-77.7, -18089.2), Valid Lower Bound: -20543.8
# Processing epoch: 410/1000
# EPOCH: 00410, Train Lower Bound: -18166.4, (-77.6, -18088.7), Valid Lower Bound: -20556.6
# Processing epoch: 411/1000
# EPOCH: 00411, Train Lower Bound: -18164.7, (-77.8, -18086.9), Valid Lower Bound: -20520.7
# ...
# Processing epoch: 476/1000
# EPOCH: 00476, Train Lower Bound: -17970.1, (-81.6, -17888.5), Valid Lower Bound: -20747.5
# Processing epoch: 477/1000
# EPOCH: 00477, Train Lower Bound: -17973.4, (-81.4, -17892.0), Valid Lower Bound: -20752.0
# Processing epoch: 478/1000
# EPOCH: 00478, Train Lower Bound: -17958.4, (-81.8, -17876.6), Valid Lower Bound: -20800.1
# Processing epoch: 479/1000
# EPOCH: 00479, Train Lower Bound: -17957.6, (-81.9, -17875.8), Valid Lower Bound: -20753.2
# Processing epoch: 480/1000
# EPOCH: 00480, Train Lower Bound: -17963.3, (-81.9, -17881.4), Valid Lower Bound: -20723.9
# Processing epoch: 481/1000
# EPOCH: 00481, Train Lower Bound: -17958.3, (-82.0, -17876.3), Valid Lower Bound: -20763.2
# Processing epoch: 482/1000
# EPOCH: 00482, Train Lower Bound: -17965.1, (-81.8, -17883.4), Valid Lower Bound: -20817.8
# Processing epoch: 483/1000
# EPOCH: 00483, Train Lower Bound: -17955.5, (-82.0, -17873.5), Valid Lower Bound: -20730.7
# Processing epoch: 484/1000
# EPOCH: 00484, Train Lower Bound: -17948.9, (-82.0, -17866.9), Valid Lower Bound: -20784.3
# Processing epoch: 485/1000
# EPOCH: 00485, Train Lower Bound: -17934.7, (-82.1, -17852.6), Valid Lower Bound: -20841.8
# Processing epoch: 486/1000
# EPOCH: 00486, Train Lower Bound: -17931.4, (-82.6, -17848.8), Valid Lower Bound: -20739.5
# Processing epoch: 487/1000
# EPOCH: 00487, Train Lower Bound: -17935.8, (-82.2, -17853.5), Valid Lower Bound: -20713.0
# Processing epoch: 488/1000
# EPOCH: 00488, Train Lower Bound: -17932.8, (-82.4, -17850.4), Valid Lower Bound: -20829.8
# Processing epoch: 489/1000
# EPOCH: 00489, Train Lower Bound: -17927.7, (-82.5, -17845.2), Valid Lower Bound: -20763.9
# Processing epoch: 490/1000
# EPOCH: 00490, Train Lower Bound: -17929.1, (-82.6, -17846.4), Valid Lower Bound: -20777.0
# Processing epoch: 491/1000
# EPOCH: 00491, Train Lower Bound: -17933.6, (-82.5, -17851.1), Valid Lower Bound: -20742.2
# Processing epoch: 492/1000
# EPOCH: 00492, Train Lower Bound: -17936.6, (-82.2, -17854.4), Valid Lower Bound: -20771.4
# Processing epoch: 493/1000
# EPOCH: 00493, Train Lower Bound: -17924.9, (-82.4, -17842.5), Valid Lower Bound: -20780.8
# Processing epoch: 494/1000
# EPOCH: 00494, Train Lower Bound: -17911.5, (-82.8, -17828.7), Valid Lower Bound: -20795.0
# Processing epoch: 495/1000
# EPOCH: 00495, Train Lower Bound: -17906.0, (-83.1, -17822.9), Valid Lower Bound: -20769.8
# Processing epoch: 496/1000
# EPOCH: 00496, Train Lower Bound: -17916.2, (-82.6, -17833.6), Valid Lower Bound: -20804.8
# Processing epoch: 497/1000
# EPOCH: 00497, Train Lower Bound: -17902.4, (-83.1, -17819.2), Valid Lower Bound: -20824.1
# Processing epoch: 498/1000
# EPOCH: 00498, Train Lower Bound: -17906.4, (-83.1, -17823.3), Valid Lower Bound: -20845.8
# Processing epoch: 499/1000
# EPOCH: 00499, Train Lower Bound: -17899.4, (-83.3, -17816.1), Valid Lower Bound: -20778.6
# Processing epoch: 500/1000
# EPOCH: 00500, Train Lower Bound: -17896.4, (-83.5, -17813.0), Valid Lower Bound: -20836.4
# Processing epoch: 501/1000
# EPOCH: 00501, Train Lower Bound: -17905.3, (-83.1, -17822.3), Valid Lower Bound: -20816.8
# Processing epoch: 502/1000
# EPOCH: 00502, Train Lower Bound: -17906.3, (-83.1, -17823.2), Valid Lower Bound: -20810.6
# Processing epoch: 503/1000
# EPOCH: 00503, Train Lower Bound: -17892.3, (-83.3, -17809.0), Valid Lower Bound: -20804.2
# Processing epoch: 504/1000
# EPOCH: 00504, Train Lower Bound: -17887.6, (-83.3, -17804.3), Valid Lower Bound: -20852.4
# Processing epoch: 505/1000
# EPOCH: 00505, Train Lower Bound: -17882.5, (-83.5, -17799.0), Valid Lower Bound: -20786.8
# Processing epoch: 506/1000
# EPOCH: 00506, Train Lower Bound: -17879.0, (-83.5, -17795.5), Valid Lower Bound: -20841.2
# Processing epoch: 507/1000
# EPOCH: 00507, Train Lower Bound: -17878.1, (-83.7, -17794.4), Valid Lower Bound: -20785.6
# Processing epoch: 508/1000
# EPOCH: 00508, Train Lower Bound: -17881.6, (-83.6, -17798.0), Valid Lower Bound: -20856.9
# Processing epoch: 509/1000
# EPOCH: 00509, Train Lower Bound: -17879.0, (-83.4, -17795.6), Valid Lower Bound: -20851.1
# Processing epoch: 510/1000
# EPOCH: 00510, Train Lower Bound: -17879.5, (-83.6, -17795.9), Valid Lower Bound: -20814.2
# Processing epoch: 511/1000
# EPOCH: 00511, Train Lower Bound: -17872.4, (-83.8, -17788.6), Valid Lower Bound: -20870.6
# Processing epoch: 512/1000
# EPOCH: 00512, Train Lower Bound: -17868.2, (-83.8, -17784.4), Valid Lower Bound: -20815.4
# Processing epoch: 513/1000
# EPOCH: 00513, Train Lower Bound: -17860.3, (-83.9, -17776.4), Valid Lower Bound: -20813.1
# Processing epoch: 514/1000
# EPOCH: 00514, Train Lower Bound: -17867.4, (-83.6, -17783.8), Valid Lower Bound: -20824.9
# Processing epoch: 515/1000
# EPOCH: 00515, Train Lower Bound: -17908.1, (-83.0, -17825.1), Valid Lower Bound: -20790.6
# Processing epoch: 516/1000
# EPOCH: 00516, Train Lower Bound: -17892.1, (-83.1, -17809.0), Valid Lower Bound: -20822.8
# Processing epoch: 517/1000
# EPOCH: 00517, Train Lower Bound: -17862.4, (-83.8, -17778.7), Valid Lower Bound: -20836.0
# Processing epoch: 518/1000
# EPOCH: 00518, Train Lower Bound: -17846.1, (-84.2, -17761.9), Valid Lower Bound: -20869.5
# Processing epoch: 519/1000
# EPOCH: 00519, Train Lower Bound: -17834.8, (-84.5, -17750.3), Valid Lower Bound: -20830.8
# Processing epoch: 520/1000
# EPOCH: 00520, Train Lower Bound: -17835.3, (-84.4, -17750.8), Valid Lower Bound: -20852.6
# Processing epoch: 521/1000
# EPOCH: 00521, Train Lower Bound: -17835.6, (-84.6, -17751.0), Valid Lower Bound: -20860.8
# Processing epoch: 522/1000
# EPOCH: 00522, Train Lower Bound: -17835.7, (-84.5, -17751.2), Valid Lower Bound: -20878.0
# Processing epoch: 523/1000
# EPOCH: 00523, Train Lower Bound: -17833.6, (-84.5, -17749.0), Valid Lower Bound: -20891.2
# Processing epoch: 524/1000
# EPOCH: 00524, Train Lower Bound: -17829.1, (-84.6, -17744.5), Valid Lower Bound: -20872.3
# Processing epoch: 525/1000
# EPOCH: 00525, Train Lower Bound: -17835.8, (-84.6, -17751.1), Valid Lower Bound: -20891.3
# Processing epoch: 526/1000
# EPOCH: 00526, Train Lower Bound: -17842.9, (-84.1, -17758.8), Valid Lower Bound: -20858.0
# Processing epoch: 527/1000
# EPOCH: 00527, Train Lower Bound: -17832.8, (-84.5, -17748.3), Valid Lower Bound: -20845.8
# Processing epoch: 528/1000
# EPOCH: 00528, Train Lower Bound: -17823.7, (-84.7, -17739.0), Valid Lower Bound: -20837.4
# Processing epoch: 529/1000
# EPOCH: 00529, Train Lower Bound: -17818.0, (-84.8, -17733.2), Valid Lower Bound: -20880.3
# Processing epoch: 530/1000
# EPOCH: 00530, Train Lower Bound: -17827.8, (-84.5, -17743.2), Valid Lower Bound: -20892.9
# Processing epoch: 531/1000
# EPOCH: 00531, Train Lower Bound: -17813.7, (-85.0, -17728.8), Valid Lower Bound: -20892.7
# Processing epoch: 532/1000
# EPOCH: 00532, Train Lower Bound: -17810.4, (-85.0, -17725.4), Valid Lower Bound: -20885.6
# Processing epoch: 533/1000
# EPOCH: 00533, Train Lower Bound: -17815.6, (-85.0, -17730.5), Valid Lower Bound: -20871.4
# Processing epoch: 534/1000
# EPOCH: 00534, Train Lower Bound: -17807.4, (-85.0, -17722.3), Valid Lower Bound: -20900.1
# Processing epoch: 535/1000
# EPOCH: 00535, Train Lower Bound: -17809.5, (-84.9, -17724.6), Valid Lower Bound: -20939.3
# Processing epoch: 536/1000
# EPOCH: 00536, Train Lower Bound: -17808.0, (-85.0, -17723.0), Valid Lower Bound: -20884.0
# Processing epoch: 537/1000
# EPOCH: 00537, Train Lower Bound: -17800.5, (-85.2, -17715.3), Valid Lower Bound: -20875.0
# Processing epoch: 538/1000
# EPOCH: 00538, Train Lower Bound: -17801.2, (-85.5, -17715.7), Valid Lower Bound: -20937.5
# Processing epoch: 539/1000
# EPOCH: 00539, Train Lower Bound: -17795.0, (-85.3, -17709.7), Valid Lower Bound: -20922.1
# Processing epoch: 540/1000
# EPOCH: 00540, Train Lower Bound: -17791.0, (-85.5, -17705.5), Valid Lower Bound: -20893.2
# Processing epoch: 541/1000
# EPOCH: 00541, Train Lower Bound: -17786.0, (-85.2, -17700.8), Valid Lower Bound: -20904.1
# Processing epoch: 542/1000
# EPOCH: 00542, Train Lower Bound: -17779.9, (-85.7, -17694.3), Valid Lower Bound: -20924.7
# Processing epoch: 543/1000
# EPOCH: 00543, Train Lower Bound: -17780.2, (-85.8, -17694.5), Valid Lower Bound: -20938.9
# Processing epoch: 544/1000
# EPOCH: 00544, Train Lower Bound: -17784.9, (-85.6, -17699.3), Valid Lower Bound: -20912.0
# Processing epoch: 545/1000
# EPOCH: 00545, Train Lower Bound: -17782.8, (-85.5, -17697.3), Valid Lower Bound: -20925.5
# Processing epoch: 546/1000
# EPOCH: 00546, Train Lower Bound: -17782.2, (-85.6, -17696.6), Valid Lower Bound: -20945.9
# Processing epoch: 547/1000
# EPOCH: 00547, Train Lower Bound: -17776.6, (-85.5, -17691.0), Valid Lower Bound: -20966.9
# Processing epoch: 548/1000
# EPOCH: 00548, Train Lower Bound: -17769.7, (-86.0, -17683.7), Valid Lower Bound: -20938.4
# Processing epoch: 549/1000
# EPOCH: 00549, Train Lower Bound: -17763.3, (-85.9, -17677.4), Valid Lower Bound: -20950.6
# Processing epoch: 550/1000
# EPOCH: 00550, Train Lower Bound: -17753.3, (-86.3, -17667.0), Valid Lower Bound: -20943.0
# Processing epoch: 551/1000
# EPOCH: 00551, Train Lower Bound: -17757.7, (-86.2, -17671.5), Valid Lower Bound: -20958.8
# Processing epoch: 552/1000
# EPOCH: 00552, Train Lower Bound: -17759.5, (-86.3, -17673.2), Valid Lower Bound: -20943.8
# Processing epoch: 553/1000
# EPOCH: 00553, Train Lower Bound: -17760.5, (-86.2, -17674.3), Valid Lower Bound: -20976.4
# Processing epoch: 554/1000
# EPOCH: 00554, Train Lower Bound: -17757.4, (-86.2, -17671.2), Valid Lower Bound: -20942.5
# Processing epoch: 555/1000
# EPOCH: 00555, Train Lower Bound: -17758.2, (-86.1, -17672.1), Valid Lower Bound: -21006.1
# Processing epoch: 556/1000
# EPOCH: 00556, Train Lower Bound: -17751.9, (-86.3, -17665.6), Valid Lower Bound: -20987.4
# Processing epoch: 557/1000
# EPOCH: 00557, Train Lower Bound: -17744.7, (-86.4, -17658.2), Valid Lower Bound: -20941.9
# Processing epoch: 558/1000
# EPOCH: 00558, Train Lower Bound: -17743.6, (-86.5, -17657.1), Valid Lower Bound: -21002.4
# Processing epoch: 559/1000
# EPOCH: 00559, Train Lower Bound: -17743.5, (-86.5, -17656.9), Valid Lower Bound: -20977.4
# Processing epoch: 560/1000
# EPOCH: 00560, Train Lower Bound: -17750.8, (-86.2, -17664.7), Valid Lower Bound: -20999.8
# Processing epoch: 561/1000
# EPOCH: 00561, Train Lower Bound: -17747.6, (-86.5, -17661.1), Valid Lower Bound: -20977.7
# Processing epoch: 562/1000
# EPOCH: 00562, Train Lower Bound: -17733.8, (-86.5, -17647.3), Valid Lower Bound: -20993.4
# Processing epoch: 563/1000
# EPOCH: 00563, Train Lower Bound: -17729.6, (-86.9, -17642.7), Valid Lower Bound: -20953.1
# Processing epoch: 564/1000
# EPOCH: 00564, Train Lower Bound: -17730.7, (-86.8, -17643.9), Valid Lower Bound: -20960.3
# Processing epoch: 565/1000
# EPOCH: 00565, Train Lower Bound: -17719.8, (-87.0, -17632.9), Valid Lower Bound: -21009.2
# Processing epoch: 566/1000
# EPOCH: 00566, Train Lower Bound: -17720.0, (-86.9, -17633.1), Valid Lower Bound: -20960.1
# Processing epoch: 567/1000
# EPOCH: 00567, Train Lower Bound: -17717.6, (-87.3, -17630.2), Valid Lower Bound: -21008.6
# Processing epoch: 568/1000
# EPOCH: 00568, Train Lower Bound: -17709.5, (-87.4, -17622.1), Valid Lower Bound: -20971.6
# Processing epoch: 569/1000
# EPOCH: 00569, Train Lower Bound: -17708.2, (-87.5, -17620.6), Valid Lower Bound: -20964.8
# Processing epoch: 570/1000
# EPOCH: 00570, Train Lower Bound: -17725.7, (-86.9, -17638.9), Valid Lower Bound: -21020.7
# Processing epoch: 571/1000
# EPOCH: 00571, Train Lower Bound: -17716.3, (-87.3, -17629.0), Valid Lower Bound: -21087.7
# Processing epoch: 572/1000
# EPOCH: 00572, Train Lower Bound: -17723.9, (-87.1, -17636.7), Valid Lower Bound: -21031.7
# Processing epoch: 573/1000
# EPOCH: 00573, Train Lower Bound: -17731.8, (-86.4, -17645.3), Valid Lower Bound: -21006.0
# Processing epoch: 574/1000
# EPOCH: 00574, Train Lower Bound: -17702.2, (-87.5, -17614.7), Valid Lower Bound: -21020.2
# Processing epoch: 575/1000
# EPOCH: 00575, Train Lower Bound: -17694.5, (-87.4, -17607.1), Valid Lower Bound: -20964.2
# Processing epoch: 576/1000
# EPOCH: 00576, Train Lower Bound: -17698.4, (-87.4, -17610.9), Valid Lower Bound: -21031.2
# Processing epoch: 577/1000
# EPOCH: 00577, Train Lower Bound: -17689.6, (-87.5, -17602.0), Valid Lower Bound: -21081.2
# Processing epoch: 578/1000
# EPOCH: 00578, Train Lower Bound: -17686.3, (-87.8, -17598.5), Valid Lower Bound: -20966.6
# Processing epoch: 579/1000
# EPOCH: 00579, Train Lower Bound: -17689.3, (-87.8, -17601.5), Valid Lower Bound: -21040.6
# Processing epoch: 580/1000
# EPOCH: 00580, Train Lower Bound: -17682.6, (-87.9, -17594.7), Valid Lower Bound: -21074.7
# Processing epoch: 581/1000
# EPOCH: 00581, Train Lower Bound: -17679.6, (-87.8, -17591.7), Valid Lower Bound: -21023.0
# Processing epoch: 582/1000
# EPOCH: 00582, Train Lower Bound: -17682.8, (-88.0, -17594.8), Valid Lower Bound: -21050.7
# Processing epoch: 583/1000
# EPOCH: 00583, Train Lower Bound: -17676.9, (-88.0, -17588.9), Valid Lower Bound: -21004.6
# Processing epoch: 584/1000
# EPOCH: 00584, Train Lower Bound: -17676.0, (-88.1, -17587.9), Valid Lower Bound: -21035.0
# Processing epoch: 585/1000
# EPOCH: 00585, Train Lower Bound: -17679.8, (-88.0, -17591.7), Valid Lower Bound: -20968.8
# Processing epoch: 586/1000
# EPOCH: 00586, Train Lower Bound: -17676.4, (-88.1, -17588.3), Valid Lower Bound: -21065.1
# Processing epoch: 587/1000
# EPOCH: 00587, Train Lower Bound: -17677.8, (-88.0, -17589.8), Valid Lower Bound: -21025.8
# Processing epoch: 588/1000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-2b669de266ae> in <module>()
# ----> 1 train_obj(data_obj.x_train, data_obj.x_valid)
#
# <ipython-input-19-6315dbffc2fd> in __call__(self, x_train, x_valid)
#      26         end = start + Train.BATCH_SIZE
#      27
# ---> 28         _, lowerbound = self.sess.run([train, lower_bound], feed_dict={x: x_train[start:end], is_training: True})
#      29
#      30         lower_bound_all.append(lowerbound)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1332   def _do_call(self, fn, *args):
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#    1336       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#    1321     def _prun_fn(handle, feed_dict, fetch_list):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1405     return tf_session.TF_SessionRun_wrapper(
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#    1409   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
x = tf.placeholder(tf.float32, [None, MyImage.IMG_SIZE_WIDTH*MyImage.IMG_SIZE_HEIGHT])
is_training = tf.placeholder(tf.bool, shape=())
sample_z_func = Model.encoder(x, is_training) # mean, var

# %%
z = tf.placeholder(tf.float32, [None, Model.Z_DIM])
sample_x_func = Model.decoder(z, is_training) # mean

# %%
def deprocess(x):
    _x = x.reshape(x.shape[0], MyImage.IMG_SIZE_WIDTH, MyImage.IMG_SIZE_HEIGHT)
    return 1 - _x

# %%
n_samples = 100

fig = plt.figure(figsize=(10, 10))

_sample_x = deprocess(data_obj.x_train[:n_samples])

for j, _x in enumerate(_sample_x):
    ax = fig.add_subplot(10, 10, j+1, xticks=[], yticks=[])
    ax.imshow(_x, 'gray')

# %%
# Encode
mean, var = train_obj.sess.run(sample_z_func, feed_dict={x: data_obj.x_train[:n_samples], is_training:False})
sample_z = mean

# Decode
sample_x = train_obj.sess.run(sample_x_func, feed_dict={z: sample_z, is_training:False})

fig = plt.figure(figsize=(10, 10))

_sample_x = deprocess(sample_x)

for j, _x in enumerate(_sample_x):
    ax = fig.add_subplot(10, 10, j+1, xticks=[], yticks=[])
    ax.imshow(_x, 'gray')

# %%
sample_z = np.random.standard_normal((n_samples, Model.Z_DIM)).astype('float32')
sample_z = train_obj.sess.run(sample_x_func, feed_dict={z: sample_z, is_training:False})

fig = plt.figure(figsize=(10, 10))

_sample_x = deprocess(sample_z)

for j, _x in enumerate(_sample_x):
    ax = fig.add_subplot(10, 10, j+1, xticks=[], yticks=[])
    ax.imshow(_x, 'gray')

# %%
# Source
x_0 = data_obj.x_train[:1]

# Target
x_1 = data_obj.x_train[1:2]

fig = plt.figure(figsize=(5, 5))
ax_0 = fig.add_subplot(1, 2, 1, xticks=[], yticks=[])
ax_0.set_title('Source image')
ax_0.imshow(deprocess(x_0)[0], 'gray')

ax_1 = fig.add_subplot(1, 2, 2, xticks=[], yticks=[])
ax_1.set_title('Target image')
ax_1.imshow(deprocess(x_1)[0], 'gray')

plt.show()

# %%
# 潜在空間に写像
sample_z_0, _ = train_obj.sess.run(sample_z_func, feed_dict={x: x_0, is_training:False})
sample_z_1, _ = train_obj.sess.run(sample_z_func, feed_dict={x: x_1, is_training:False})

move = sample_z_1 - sample_z_0

fig = plt.figure(figsize=(15, 15))

for i, j in enumerate(np.linspace(0, 1, 10)):
    # 線形補間
    _z = sample_z_0 + j*move
    sample_x = train_obj.sess.run(sample_x_func, feed_dict={z: _z, is_training:False})

    ax = fig.add_subplot(1, 10, i+1, xticks=[], yticks=[])
    ax.imshow(deprocess(sample_x)[0], 'gray')
